# %% [markdown]
# <a href="https://colab.research.google.com/github/tram-tr/predicting-molecular-properties/blob/main/models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# need authorization code to mount drive
from google.colab import drive
drive.mount('/content/drive')
# %env KAGGLE_CONFIG_DIR=/content/drive/My Drive/Colab Notebooks/Kaggle
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# env: KAGGLE_CONFIG_DIR=/content/drive/My Drive/Colab Notebooks/Kaggle

# %%
# !pip install kaggle
# !kaggle competitions download -c champs-scalar-coupling
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)
# champs-scalar-coupling.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !pip install ase
# Out:
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (3.22.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from ase) (3.7.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->ase) (1.16.0)

# %%
#!unzip /content/champs-scalar-coupling.zip

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import math
from numpy.linalg import svd
import ase
from ase import Atoms
import ase.visualize
import warnings
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from scipy.stats import randint, uniform
import xgboost as xgb
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import lightgbm as lgb
import logging
warnings.filterwarnings('ignore')
logging.basicConfig(level=logging.WARNING)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train = pd.read_csv('train.csv', nrows=500_000)
test = pd.read_csv('test.csv')
structures = pd.read_csv('structures.csv')
contributions = pd.read_csv('scalar_coupling_contributions.csv')
mulliken = pd.read_csv('mulliken_charges.csv')
test_mulliken = pd.read_csv('mulliken_charges_test_set.csv')

# %%
train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4659076  dsgdb9nsd_000004             2             0  2JHC
# 1  4659077  dsgdb9nsd_000004             2             1  1JHC
# 2  4659078  dsgdb9nsd_000004             2             3  3JHH
# 3  4659079  dsgdb9nsd_000004             3             0  1JHC
# 4  4659080  dsgdb9nsd_000004             3             1  2JHC

# %%
train = pd.merge(train, contributions, how = 'left',
                  left_on  = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'],
                  right_on = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'])
test = pd.merge(test, contributions, how = 'left',
                  left_on  = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'],
                  right_on = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'])

# %%
atomic_radius = {'H':0.38, 'C':0.77, 'N':0.75, 'O':0.73, 'F':0.71}
fudge_factor = 0.05
atomic_radius_fudge = {k:v + fudge_factor for k,v in atomic_radius.items()}
electronegativity = {'H':2.2, 'C':2.55, 'N':3.04, 'O':3.44, 'F':3.98}
max_atoms = 28

# %%
atoms = structures['atom'].values
atoms_en = [electronegativity[x] for x in tqdm(atoms)]
atoms_rad = [atomic_radius[x] for x in tqdm(atoms)]
structures['e_neg'] = atoms_en
structures['rad'] = atoms_rad
# Out:
#   0%|          | 0/2358875 [00:00<?, ?it/s]
#   0%|          | 0/2358875 [00:00<?, ?it/s]

# %%
atom_idx = structures['atom_index'].values
coords = structures[['x', 'y', 'z']].values
molecules = structures['molecule_name'].values
rads = structures['rad'].values
n_rows = np.arange(len(structures))

# calculate bond distances
bonds = np.zeros((len(structures) + 1, max_atoms + 1), dtype=np.int8)
bond_dists = np.zeros((len(structures) + 1, max_atoms + 1), dtype=np.float32)

coords_temp = coords
molecules_temp = molecules
rads_temp = rads

for i in tqdm(range(max_atoms - 1)):
  coords_temp = np.roll(coords_temp, -1, axis=0)
  molecules_temp = np.roll(molecules_temp, -1, axis=0)
  rads_temp = np.roll(rads_temp, -1, axis=0)

  mask = np.where(molecules==molecules_temp, 1, 0)
  dists = np.linalg.norm(coords - coords_temp, axis=1) * mask
  rad_bond = rads + rads_temp

  bond = np.where(np.logical_and(dists > 0.0001, dists < rad_bond), 1, 0)

  source_row = n_rows
  target_row = source_row + i + 1
  target_row = np.where(np.logical_or(target_row > len(structures), mask==0), len(structures), target_row)

  source_atom = atom_idx
  target_atom = atom_idx + i + 1
  target_atom = np.where(np.logical_or(target_atom > max_atoms, mask==0), max_atoms, target_atom)

  bonds[(source_row, target_atom)] = bond
  bonds[(target_row, source_atom)] = bond
  bond_dists[(source_row, target_atom)] = dists
  bond_dists[(target_row, source_atom)] = dists

bonds = np.delete(bonds, axis=0, obj=-1) # remove dummy row
bonds = np.delete(bonds, axis=1, obj=-1) # remove dummy col
bond_dists = np.delete(bond_dists, axis=0, obj=-1) # remove dummy row
bond_dists = np.delete(bond_dists, axis=1, obj=-1) # remove dummy col

bonds_numeric = [[i for i,x in enumerate(row) if x] for row in tqdm(bonds)]
bond_lengths = [[dist for i,dist in enumerate(row) if i in bonds_numeric[j]] for j,row in enumerate(tqdm(bond_dists))]
bond_lengths_mean = [ np.mean(x) for x in bond_lengths]
n_bonds = [len(x) for x in bonds_numeric]
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/2358875 [00:00<?, ?it/s]
#   0%|          | 0/2358875 [00:00<?, ?it/s]

# %%
bond_data = {'n_bonds':n_bonds, 'bond_lengths_mean': bond_lengths_mean }
bond_df = pd.DataFrame(bond_data)
structures = structures.join(bond_df)

# %%
structures.head(10)
# Out:
#       molecule_name  atom_index atom         x         y         z  e_neg  \
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001   2.55
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976   2.20
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277   2.20
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644   2.20
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397   2.20
# 5  dsgdb9nsd_000002           0    N -0.040426  1.024108  0.062564   3.04
# 6  dsgdb9nsd_000002           1    H  0.017257  0.012545 -0.027377   2.20
# 7  dsgdb9nsd_000002           2    H  0.915789  1.358745 -0.028758   2.20
# 8  dsgdb9nsd_000002           3    H -0.520278  1.343532 -0.775543   2.20
# 9  dsgdb9nsd_000003           0    O -0.034360  0.977540  0.007602   3.44
#
#     rad  n_bonds  bond_lengths_mean
# 0  0.77        4           1.091950
# 1  0.38        1           1.091953
# 2  0.38        1           1.091952
# 3  0.38        1           1.091946
# 4  0.38        1           1.091948
# 5  0.75        3           1.017195
# 6  0.38        1           1.017190
# 7  0.38        1           1.017187
# 8  0.38        1           1.017208
# 9  0.73        2           0.962107

# %%
def map_atom_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])

    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

train = map_atom_info(train, 0)
train = map_atom_info(train, 1)
test = map_atom_info(test, 0)
test = map_atom_info(test, 1)

# %%
train.head(10)
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
# 5   5  dsgdb9nsd_000001             2             3  2JHH
# 6   6  dsgdb9nsd_000001             2             4  2JHH
# 7   7  dsgdb9nsd_000001             3             0  1JHC
# 8   8  dsgdb9nsd_000001             3             4  2JHH
# 9   9  dsgdb9nsd_000001             4             0  1JHC
#
#    scalar_coupling_constant       fc        sd      pso       dso  ...  \
# 0                   84.8076  83.0224  0.254579  1.25862  0.272010  ...
# 1                  -11.2570 -11.0347  0.352978  2.85839 -3.433600  ...
# 2                  -11.2548 -11.0325  0.352944  2.85852 -3.433870  ...
# 3                  -11.2543 -11.0319  0.352934  2.85855 -3.433930  ...
# 4                   84.8074  83.0222  0.254585  1.25861  0.272013  ...
# 5                  -11.2541 -11.0317  0.352932  2.85856 -3.433950  ...
# 6                  -11.2548 -11.0324  0.352943  2.85853 -3.433870  ...
# 7                   84.8093  83.0241  0.254634  1.25856  0.272012  ...
# 8                  -11.2543 -11.0319  0.352943  2.85856 -3.433930  ...
# 9                   84.8095  83.0243  0.254628  1.25856  0.272012  ...
#
#    bond_lengths_mean_x atom_index_y  atom_1       x_1       y_1       z_1  \
# 0             1.091953            0       C -0.012698  1.085804  0.008001
# 1             1.091953            2       H  1.011731  1.463751  0.000277
# 2             1.091953            3       H -0.540815  1.447527 -0.876644
# 3             1.091953            4       H -0.523814  1.437933  0.906397
# 4             1.091952            0       C -0.012698  1.085804  0.008001
# 5             1.091952            3       H -0.540815  1.447527 -0.876644
# 6             1.091952            4       H -0.523814  1.437933  0.906397
# 7             1.091946            0       C -0.012698  1.085804  0.008001
# 8             1.091946            4       H -0.523814  1.437933  0.906397
# 9             1.091948            0       C -0.012698  1.085804  0.008001
#
#    e_neg_y  rad_y  n_bonds_y  bond_lengths_mean_y
# 0     2.55   0.77          4             1.091950
# 1     2.20   0.38          1             1.091952
# 2     2.20   0.38          1             1.091946
# 3     2.20   0.38          1             1.091948
# 4     2.55   0.77          4             1.091950
# 5     2.20   0.38          1             1.091946
# 6     2.20   0.38          1             1.091948
# 7     2.55   0.77          4             1.091950
# 8     2.20   0.38          1             1.091948
# 9     2.55   0.77          4             1.091950
#
# [10 rows x 28 columns]

# %%
mulliken = mulliken.rename({'atom_index': 'atom_index_0',
                          'mulliken_charge': 'mulliken_charge_0'}, axis=1)
train = train.merge(mulliken, on=['molecule_name', 'atom_index_0'])
mulliken = mulliken.rename({'atom_index_0': 'atom_index_1',
                          'mulliken_charge_0': 'mulliken_charge_1'}, axis=1)
train = train.merge(mulliken, on=['molecule_name', 'atom_index_1'])

test_mulliken = test_mulliken.rename({'atom_index': 'atom_index_0',
                          'mulliken_charge': 'mulliken_charge_0'}, axis=1)
test = test.merge(test_mulliken, on=['molecule_name', 'atom_index_0'])
test_mulliken = test_mulliken.rename({'atom_index_0': 'atom_index_1',
                          'mulliken_charge_0': 'mulliken_charge_1'}, axis=1)
test = test.merge(test_mulliken, on=['molecule_name', 'atom_index_1'])

# %%
train.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant', 'fc', 'sd', 'pso', 'dso', 'atom_index_x',
#        'atom_0', 'x_0', 'y_0', 'z_0', 'e_neg_x', 'rad_x', 'n_bonds_x',
#        'bond_lengths_mean_x', 'atom_index_y', 'atom_1', 'x_1', 'y_1', 'z_1',
#        'e_neg_y', 'rad_y', 'n_bonds_y', 'bond_lengths_mean_y',
#        'mulliken_charge_0', 'mulliken_charge_1'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type', 'fc',
#        'sd', 'pso', 'dso', 'atom_index_x', 'atom_0', 'x_0', 'y_0', 'z_0',
#        'e_neg_x', 'rad_x', 'n_bonds_x', 'bond_lengths_mean_x', 'atom_index_y',
#        'atom_1', 'x_1', 'y_1', 'z_1', 'e_neg_y', 'rad_y', 'n_bonds_y',
#        'bond_lengths_mean_y', 'mulliken_charge_0', 'mulliken_charge_1'],
#       dtype='object')

# %%
external_data_0 = pd.DataFrame(data={
    'atom_0': ['C', 'H', 'N', 'O', 'F'],
    'atom_0_en': [2.55, 2.20, 3.04, 3.44, 3.98],
    'atomic_mass_0': [12.0107, 1.00784, 14.0067, 15.999, 18.9984],
    'valence_electrons_0': [4, 1, 5, 6, 7]
})

external_data_1 = pd.DataFrame(data={
    'atom_1': ['C', 'H', 'N', 'O', 'F'],
    'atom_1_en': [2.55, 2.20, 3.04, 3.44, 3.98],
    'atomic_mass_1': [12.0107, 1.00784, 14.0067, 15.999, 18.9984],
    'valence_electrons_1': [4, 1, 5, 6, 7]
})

def distance_features(df):
    df['dist'] = np.linalg.norm(df[['x_0', 'y_0', 'z_0']].values - df[['x_1', 'y_1', 'z_1']].values, axis=1)
    df['j_bond'] = df['type'].str[2:]
    df['j_type'] = df['type'].str[:2]
    df['mu_0'] = np.sqrt(df['x_0'].values**2 + df['y_0'].values**2 + df['z_0'].values**2)
    df['mu_1'] = np.sqrt(df['x_1'].values**2 + df['y_1'].values**2 + df['z_1'].values**2)
    df = df.merge(external_data_0, on='atom_0', how='left')
    df = df.merge(external_data_1, on='atom_1', how='left')
    df['delta_en'] = (df['atom_0_en'] - df['atom_1_en']).abs()
    df['molecule_couples'] = df.groupby('molecule_name')['id'].transform('count')
    df['molecule_dist_mean'] = df.groupby('molecule_name')['dist'].transform('mean')
    df['molecule_dist_min'] = df.groupby('molecule_name')['dist'].transform('min')
    df['molecule_dist_max'] = df.groupby('molecule_name')['dist'].transform('max')
    df['atom_0_couples_count'] = df.groupby(['molecule_name', 'atom_index_0'])['id'].transform('count')
    df['atom_1_couples_count'] = df.groupby(['molecule_name', 'atom_index_1'])['id'].transform('count')
    df['molecule_atom_index_0_x_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['x_1'].transform('std')
    df['molecule_atom_index_0_y_1_mean'] = df.groupby(['molecule_name', 'atom_index_0'])['y_1'].transform('mean')
    df['molecule_atom_index_0_y_1_mean_diff'] = df[f'molecule_atom_index_0_y_1_mean'] - df['y_1']
    df['molecule_atom_index_0_y_1_mean_div'] = df[f'molecule_atom_index_0_y_1_mean'] / df['y_1']
    df['molecule_atom_index_0_y_1_max'] = df.groupby(['molecule_name', 'atom_index_0'])['y_1'].transform('max')
    df['molecule_atom_index_0_y_1_max_diff'] = df[f'molecule_atom_index_0_y_1_max'] - df['y_1']
    df['molecule_atom_index_0_y_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['y_1'].transform('std')
    df['molecule_atom_index_0_z_1_std'] = df.groupby(['molecule_name', 'atom_index_0'])['z_1'].transform('std')
    df['molecule_atom_index_0_dist_mean'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('mean')
    df['molecule_atom_index_0_dist_mean_diff'] = df[f'molecule_atom_index_0_dist_mean'] - df['dist']
    df['molecule_atom_index_0_dist_mean_div'] = df[f'molecule_atom_index_0_dist_mean'] / df['dist']
    df['molecule_atom_index_0_dist_max'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('max')
    df['molecule_atom_index_0_dist_max_diff'] = df[f'molecule_atom_index_0_dist_max'] - df['dist']
    df['molecule_atom_index_0_dist_max_div'] = df[f'molecule_atom_index_0_dist_max'] / df['dist']
    df['molecule_atom_index_0_dist_min'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('min')
    df['molecule_atom_index_0_dist_min_diff'] = df[f'molecule_atom_index_0_dist_min'] - df['dist']
    df['molecule_atom_index_0_dist_min_div'] = df[f'molecule_atom_index_0_dist_min'] / df['dist']
    df['molecule_atom_index_0_dist_std'] = df.groupby(['molecule_name', 'atom_index_0'])['dist'].transform('std')
    df['molecule_atom_index_0_dist_std_diff'] = df[f'molecule_atom_index_0_dist_std'] - df['dist']
    df['molecule_atom_index_0_dist_std_div'] = df[f'molecule_atom_index_0_dist_std'] / df['dist']
    df['molecule_atom_index_1_dist_mean'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('mean')
    df['molecule_atom_index_1_dist_mean_diff'] = df[f'molecule_atom_index_1_dist_mean'] - df['dist']
    df['molecule_atom_index_1_dist_mean_div'] = df[f'molecule_atom_index_1_dist_mean'] / df['dist']
    df['molecule_atom_index_1_dist_max'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('max')
    df['molecule_atom_index_1_dist_max_diff'] = df[f'molecule_atom_index_1_dist_max'] - df['dist']
    df['molecule_atom_index_1_dist_max_div'] = df[f'molecule_atom_index_1_dist_max'] / df['dist']
    df['molecule_atom_index_1_dist_min'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('min')
    df['molecule_atom_index_1_dist_min_diff'] = df[f'molecule_atom_index_1_dist_min'] - df['dist']
    df['molecule_atom_index_1_dist_min_div'] = df[f'molecule_atom_index_1_dist_min'] / df['dist']
    df['molecule_atom_index_1_dist_std'] = df.groupby(['molecule_name', 'atom_index_1'])['dist'].transform('std')
    df['molecule_atom_index_1_dist_std_diff'] = df[f'molecule_atom_index_1_dist_std'] - df['dist']
    df['molecule_atom_index_1_dist_std_div'] = df[f'molecule_atom_index_1_dist_std'] / df['dist']
    df['molecule_atom_1_dist_mean'] = df.groupby(['molecule_name', 'atom_1'])['dist'].transform('mean')
    df['molecule_atom_1_dist_min'] = df.groupby(['molecule_name', 'atom_1'])['dist'].transform('min')
    df['molecule_atom_1_dist_min_diff'] = df[f'molecule_atom_1_dist_min'] - df['dist']
    df['molecule_atom_1_dist_min_div'] = df[f'molecule_atom_1_dist_min'] / df['dist']
    df['molecule_atom_1_dist_std'] = df.groupby(['molecule_name', 'atom_1'])['dist'].transform('std')
    df['molecule_atom_1_dist_std_diff'] = df[f'molecule_atom_1_dist_std'] - df['dist']
    df = reduce_mem_usage(df)
    return df

# %%
train = distance_features(train)
train.head(10)
# Out:
# Mem. usage decreased to 95.84 Mb (70.8% reduction)
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   4  dsgdb9nsd_000001             2             0  1JHC
# 2   7  dsgdb9nsd_000001             3             0  1JHC
# 3   9  dsgdb9nsd_000001             4             0  1JHC
# 4   1  dsgdb9nsd_000001             1             2  2JHH
# 5   2  dsgdb9nsd_000001             1             3  2JHH
# 6   5  dsgdb9nsd_000001             2             3  2JHH
# 7   3  dsgdb9nsd_000001             1             4  2JHH
# 8   6  dsgdb9nsd_000001             2             4  2JHH
# 9   8  dsgdb9nsd_000001             3             4  2JHH
#
#    scalar_coupling_constant        fc        sd       pso       dso  ...  \
# 0                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 1                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 2                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 3                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 4                -11.257812 -11.03125  0.353027  2.857422 -3.433594  ...
# 5                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 6                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 7                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 8                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 9                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
#
#    molecule_atom_index_1_dist_min_div molecule_atom_index_1_dist_std  \
# 0                                 1.0                       0.000003
# 1                                 1.0                       0.000003
# 2                                 1.0                       0.000003
# 3                                 1.0                       0.000003
# 4                                 1.0                            NaN
# 5                                 1.0                       0.000007
# 6                                 1.0                       0.000007
# 7                                 1.0                       0.000005
# 8                                 1.0                       0.000005
# 9                                 1.0                       0.000005
#
#    molecule_atom_index_1_dist_std_diff  molecule_atom_index_1_dist_std_div  \
# 0                            -1.091797                            0.000003
# 1                            -1.091797                            0.000003
# 2                            -1.091797                            0.000003
# 3                            -1.091797                            0.000003
# 4                                  NaN                                 NaN
# 5                            -1.783203                            0.000004
# 6                            -1.783203                            0.000004
# 7                            -1.783203                            0.000003
# 8                            -1.783203                            0.000003
# 9                            -1.783203                            0.000003
#
#    molecule_atom_1_dist_mean  molecule_atom_1_dist_min  \
# 0                   1.091797                  1.091797
# 1                   1.091797                  1.091797
# 2                   1.091797                  1.091797
# 3                   1.091797                  1.091797
# 4                   1.783203                  1.783203
# 5                   1.783203                  1.783203
# 6                   1.783203                  1.783203
# 7                   1.783203                  1.783203
# 8                   1.783203                  1.783203
# 9                   1.783203                  1.783203
#
#    molecule_atom_1_dist_min_diff  molecule_atom_1_dist_min_div  \
# 0                      -0.000007                           1.0
# 1                      -0.000005                           1.0
# 2                       0.000000                           1.0
# 3                      -0.000001                           1.0
# 4                       0.000000                           1.0
# 5                      -0.000028                           1.0
# 6                      -0.000038                           1.0
# 7                      -0.000037                           1.0
# 8                      -0.000029                           1.0
# 9                      -0.000028                           1.0
#
#    molecule_atom_1_dist_std  molecule_atom_1_dist_std_diff
# 0                  0.000003                      -1.091797
# 1                  0.000003                      -1.091797
# 2                  0.000003                      -1.091797
# 3                  0.000003                      -1.091797
# 4                  0.000014                      -1.783203
# 5                  0.000014                      -1.783203
# 6                  0.000014                      -1.783203
# 7                  0.000014                      -1.783203
# 8                  0.000014                      -1.783203
# 9                  0.000014                      -1.783203
#
# [10 rows x 86 columns]

# %%
test = distance_features(test)
test = test.drop(['fc', 'sd', 'pso', 'dso'], axis=1)
test.head()
# Out:
# Mem. usage decreased to 186.14 Mb (67.4% reduction)
#         id     molecule_name  atom_index_0  atom_index_1  type  atom_index_x  \
# 0  4659076  dsgdb9nsd_000004             2             0  2JHC             2
# 1  4659079  dsgdb9nsd_000004             3             0  1JHC             3
# 2  4659077  dsgdb9nsd_000004             2             1  1JHC             2
# 3  4659080  dsgdb9nsd_000004             3             1  2JHC             3
# 4  4659078  dsgdb9nsd_000004             2             3  3JHH             2
#
#   atom_0       x_0  y_0  z_0  ...  molecule_atom_index_1_dist_min_div  \
# 0      H -1.662109  0.0  1.0  ...                            0.469727
# 1      H  1.662109  0.0  1.0  ...                            1.000000
# 2      H -1.662109  0.0  1.0  ...                            1.000000
# 3      H  1.662109  0.0  1.0  ...                            0.469727
# 4      H -1.662109  0.0  1.0  ...                            1.000000
#
#    molecule_atom_index_1_dist_std  molecule_atom_index_1_dist_std_diff  \
# 0                        0.847656                            -1.413086
# 1                        0.847656                            -0.214233
# 2                        0.847656                            -0.214233
# 3                        0.847656                            -1.413086
# 4                             NaN                                  NaN
#
#    molecule_atom_index_1_dist_std_div  molecule_atom_1_dist_mean  \
# 0                             0.37500                   1.662109
# 1                             0.79834                   1.662109
# 2                             0.79834                   1.662109
# 3                             0.37500                   1.662109
# 4                                 NaN                   3.324219
#
#   molecule_atom_1_dist_min  molecule_atom_1_dist_min_diff  \
# 0                 1.062500                      -1.199219
# 1                 1.062500                       0.000000
# 2                 1.062500                       0.000000
# 3                 1.062500                      -1.199219
# 4                 3.324219                       0.000000
#
#    molecule_atom_1_dist_min_div  molecule_atom_1_dist_std  \
# 0                      0.469727                  0.692383
# 1                      1.000000                  0.692383
# 2                      1.000000                  0.692383
# 3                      0.469727                  0.692383
# 4                      1.000000                       NaN
#
#    molecule_atom_1_dist_std_diff
# 0                      -1.569336
# 1                      -0.369873
# 2                      -0.369873
# 3                      -1.569336
# 4                            NaN
#
# [5 rows x 81 columns]

# %%
train.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant', 'fc', 'sd', 'pso', 'dso', 'atom_index_x',
#        'atom_0', 'x_0', 'y_0', 'z_0', 'e_neg_x', 'rad_x', 'n_bonds_x',
#        'bond_lengths_mean_x', 'atom_index_y', 'atom_1', 'x_1', 'y_1', 'z_1',
#        'e_neg_y', 'rad_y', 'n_bonds_y', 'bond_lengths_mean_y',
#        'mulliken_charge_0', 'mulliken_charge_1', 'dist', 'j_bond', 'j_type',
#        'mu_0', 'mu_1', 'atom_0_en', 'atomic_mass_0', 'valence_electrons_0',
#        'atom_1_en', 'atomic_mass_1', 'valence_electrons_1', 'delta_en',
#        'molecule_couples', 'molecule_dist_mean', 'molecule_dist_min',
#        'molecule_dist_max', 'atom_0_couples_count', 'atom_1_couples_count',
#        'molecule_atom_index_0_x_1_std', 'molecule_atom_index_0_y_1_mean',
#        'molecule_atom_index_0_y_1_mean_diff',
#        'molecule_atom_index_0_y_1_mean_div', 'molecule_atom_index_0_y_1_max',
#        'molecule_atom_index_0_y_1_max_diff', 'molecule_atom_index_0_y_1_std',
#        'molecule_atom_index_0_z_1_std', 'molecule_atom_index_0_dist_mean',
#        'molecule_atom_index_0_dist_mean_diff',
#        'molecule_atom_index_0_dist_mean_div', 'molecule_atom_index_0_dist_max',
#        'molecule_atom_index_0_dist_max_diff',
#        'molecule_atom_index_0_dist_max_div', 'molecule_atom_index_0_dist_min',
#        'molecule_atom_index_0_dist_min_diff',
#        'molecule_atom_index_0_dist_min_div', 'molecule_atom_index_0_dist_std',
#        'molecule_atom_index_0_dist_std_diff',
#        'molecule_atom_index_0_dist_std_div', 'molecule_atom_index_1_dist_mean',
#        'molecule_atom_index_1_dist_mean_diff',
#        'molecule_atom_index_1_dist_mean_div', 'molecule_atom_index_1_dist_max',
#        'molecule_atom_index_1_dist_max_diff',
#        'molecule_atom_index_1_dist_max_div', 'molecule_atom_index_1_dist_min',
#        'molecule_atom_index_1_dist_min_diff',
#        'molecule_atom_index_1_dist_min_div', 'molecule_atom_index_1_dist_std',
#        'molecule_atom_index_1_dist_std_diff',
#        'molecule_atom_index_1_dist_std_div', 'molecule_atom_1_dist_mean',
#        'molecule_atom_1_dist_min', 'molecule_atom_1_dist_min_diff',
#        'molecule_atom_1_dist_min_div', 'molecule_atom_1_dist_std',
#        'molecule_atom_1_dist_std_diff'],
#       dtype='object')

# %%
# PCA + SVD
# get the principal eigenvector of molecule axis
def PCA_SVD(a):
  a_mean = a.mean(axis=1)
  #normalise
  a = (a.T - a_mean.T).T
  u, s, v = svd(a.T)
  return(v[0])

# get the plane with minimum sum distance from the nuclei
def get_plane(a):
  a = np.reshape(a, (a.shape[0], -1))
  centroid = a.mean(axis=1)
  #normalise
  x = a - centroid[:,np.newaxis]
  m = np.dot(x, x.T)
  return(centroid, svd(m)[0][:,-1])

# %%
def bond_features(df):
  size_list = []
  flatness = []
  bond_angle_plane = []
  bond_angle_axis = []
  diheral_angle = []

  molecule_names = np.unique(df.molecule_name.values.flatten())

  for i in tqdm(range(len(molecule_names))):
    molecule = molecule_names[i]

    # get structure and bond information for each molecule
    struct = structures.loc[structures.molecule_name==molecule, :]
    bonds = df.loc[df.molecule_name==molecule, :]

    # number of constituent atoms
    size = len(struct)
    size_list.extend(np.full(len(bonds), size))

    # nuclei coordinates
    coords = np.column_stack([struct.x.values, struct.y.values, struct.z.values]).T

    # principal axis of molecular alignment
    axis_vector = PCA_SVD(coords)

    # get flatness metric and plane angles for binds if nuclei > 3
    if size > 3:
      coords = coords - coords.mean()
      # get best fitting 2D plane
      ctr, norm = get_plane(coords)

      # calculate distances of each atom from plane
      dists = np.zeros(size)
      for j in range(size):
        dists[j] = np.dot(norm, coords[:, j] - ctr)

      dist = abs(dists).sum()/len(dists)
      flatness.extend(np.full(len(bonds), dist))

      # get angle subtented by each atomic bind and plane
      for j in range(len(bonds)):
          # get atom index numbers for this bond
          atom1 = bonds.atom_index_0.values[j]
          atom2 = bonds.atom_index_1.values[j]

          # get 3D coords
          atom1_coords = coords[:, atom1]
          atom2_coords = coords[:, atom2]

          # bond vector
          atom_vec = np.array([atom1_coords[0] - atom2_coords[0],
                                atom1_coords[1] - atom2_coords[1],
                                atom1_coords[2] - atom2_coords[2]])

          # get bond angles
          angle = np.dot(norm, atom_vec)/(np.linalg.norm(norm)*np.linalg.norm(atom_vec))
          axis_angle = np.dot(axis_vector, atom_vec)/(np.linalg.norm(norm)*np.linalg.norm(atom_vec))

          angle = math.degrees(np.arccos(angle))
          axis_angle = math.degrees(np.arccos(axis_angle))

          if angle > 90:
              angle = 180 - angle

          if axis_angle > 90:
              axis_angle = 180 - axis_angle

          angle = 90 - angle
          axis_angle = 90 - axis_angle
          bond_angle_plane.append(angle)
          bond_angle_axis.append(axis_angle)

    else:
      flatness.extend(np.full(len(bonds), np.nan))
      bond_angle_plane.extend(np.full(len(bonds), np.nan))

      for j in range(len(bonds)):
        # get atom index numbers for this bond
        atom1 = bonds.atom_index_0.values[j]
        atom2 = bonds.atom_index_1.values[j]

        # get 3D coords
        atom1_coords = coords[:, atom1]
        atom2_coords = coords[:, atom2]

        # bond vector
        atom_vec = np.array([atom1_coords[0] - atom2_coords[0],
                              atom1_coords[1] - atom2_coords[1],
                              atom1_coords[2] - atom2_coords[2]])

        # get bond angles
        axis_angle = np.dot(axis_vector, atom_vec)/(np.linalg.norm(axis_vector)*np.linalg.norm(atom_vec))

        # standardise to degrees <= 90
        axis_angle = math.degrees(np.arccos(axis_angle))

        if axis_angle > 90:
            axis_angle = 180 - axis_angle

        axis_angle = 90 - axis_angle
        bond_angle_axis.append(axis_angle)

  df['num_atoms'] = np.asarray(size_list)
  df['flatness'] = np.asarray(flatness)
  df['bond_angle_plane'] = np.asarray(bond_angle_plane)
  df['bond_angle_axis'] = np.asarray(bond_angle_axis)

  return df

# %%
train = bond_features(train)
train.head(10)
# Out:
#   0%|          | 0/10398 [00:00<?, ?it/s]
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   4  dsgdb9nsd_000001             2             0  1JHC
# 2   7  dsgdb9nsd_000001             3             0  1JHC
# 3   9  dsgdb9nsd_000001             4             0  1JHC
# 4   1  dsgdb9nsd_000001             1             2  2JHH
# 5   2  dsgdb9nsd_000001             1             3  2JHH
# 6   5  dsgdb9nsd_000001             2             3  2JHH
# 7   3  dsgdb9nsd_000001             1             4  2JHH
# 8   6  dsgdb9nsd_000001             2             4  2JHH
# 9   8  dsgdb9nsd_000001             3             4  2JHH
#
#    scalar_coupling_constant        fc        sd       pso       dso  ...  \
# 0                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 1                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 2                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 3                 84.812500  83.00000  0.254639  1.258789  0.271973  ...
# 4                -11.257812 -11.03125  0.353027  2.857422 -3.433594  ...
# 5                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 6                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 7                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 8                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
# 9                -11.257812 -11.03125  0.353027  2.859375 -3.433594  ...
#
#    molecule_atom_1_dist_mean molecule_atom_1_dist_min  \
# 0                   1.091797                 1.091797
# 1                   1.091797                 1.091797
# 2                   1.091797                 1.091797
# 3                   1.091797                 1.091797
# 4                   1.783203                 1.783203
# 5                   1.783203                 1.783203
# 6                   1.783203                 1.783203
# 7                   1.783203                 1.783203
# 8                   1.783203                 1.783203
# 9                   1.783203                 1.783203
#
#    molecule_atom_1_dist_min_diff  molecule_atom_1_dist_min_div  \
# 0                      -0.000007                           1.0
# 1                      -0.000005                           1.0
# 2                       0.000000                           1.0
# 3                      -0.000001                           1.0
# 4                       0.000000                           1.0
# 5                      -0.000028                           1.0
# 6                      -0.000038                           1.0
# 7                      -0.000037                           1.0
# 8                      -0.000029                           1.0
# 9                      -0.000028                           1.0
#
#    molecule_atom_1_dist_std  molecule_atom_1_dist_std_diff  num_atoms  \
# 0                  0.000003                      -1.091797          5
# 1                  0.000003                      -1.091797          5
# 2                  0.000003                      -1.091797          5
# 3                  0.000003                      -1.091797          5
# 4                  0.000014                      -1.783203          5
# 5                  0.000014                      -1.783203          5
# 6                  0.000014                      -1.783203          5
# 7                  0.000014                      -1.783203          5
# 8                  0.000014                      -1.783203          5
# 9                  0.000014                      -1.783203          5
#
#    flatness  bond_angle_plane  bond_angle_axis
# 0  0.443764         52.084398        34.460611
# 1  0.443764         50.858665        36.069177
# 2  0.443764         13.909861        35.642512
# 3  0.443764         13.124885        34.877747
# 4  0.443764         73.351062         0.804265
# 5  0.443764         39.073948        44.696355
# 6  0.443764         19.131573        45.838738
# 7  0.443764         20.124219        44.160617
# 8  0.443764         37.879628        45.292858
# 9  0.443764         16.634444         0.382380
#
# [10 rows x 90 columns]

# %%
test = bond_features(test)
test.head(10)
# Out:
#   0%|          | 0/16057 [00:00<?, ?it/s]
#         id     molecule_name  atom_index_0  atom_index_1  type  atom_index_x  \
# 0  4659076  dsgdb9nsd_000004             2             0  2JHC             2
# 1  4659079  dsgdb9nsd_000004             3             0  1JHC             3
# 2  4659077  dsgdb9nsd_000004             2             1  1JHC             2
# 3  4659080  dsgdb9nsd_000004             3             1  2JHC             3
# 4  4659078  dsgdb9nsd_000004             2             3  3JHH             2
# 5  4659105  dsgdb9nsd_000015             3             0  1JHC             3
# 6  4659109  dsgdb9nsd_000015             4             0  1JHC             4
# 7  4659112  dsgdb9nsd_000015             5             0  1JHC             5
# 8  4659114  dsgdb9nsd_000015             6             0  3JHC             6
# 9  4659118  dsgdb9nsd_000015             7             0  3JHC             7
#
#   atom_0       x_0       y_0       z_0  ...  molecule_atom_1_dist_mean  \
# 0      H -1.662109  0.000000  1.000000  ...                   1.662109
# 1      H  1.662109  0.000000  1.000000  ...                   1.662109
# 2      H -1.662109  0.000000  1.000000  ...                   1.662109
# 3      H  1.662109  0.000000  1.000000  ...                   1.662109
# 4      H -1.662109  0.000000  1.000000  ...                   3.324219
# 5      H  1.004883  1.810547  0.004658  ...                   1.973633
# 6      H -0.546875  1.792969 -0.872559  ...                   1.973633
# 7      H -0.529785  1.722656  0.911133  ...                   1.973633
# 8      H  0.139893 -0.256104 -2.050781  ...                   1.973633
# 9      H  1.692383 -0.238647 -1.174805  ...                   1.973633
#
#    molecule_atom_1_dist_min  molecule_atom_1_dist_min_diff  \
# 0                  1.062500                      -1.199219
# 1                  1.062500                       0.000000
# 2                  1.062500                       0.000000
# 3                  1.062500                      -1.199219
# 4                  3.324219                       0.000000
# 5                  1.092773                      -0.009476
# 6                  1.092773                      -0.009476
# 7                  1.092773                       0.000000
# 8                  1.092773                      -1.547852
# 9                  1.092773                      -1.546875
#
#    molecule_atom_1_dist_min_div  molecule_atom_1_dist_std  \
# 0                      0.469727                  0.692383
# 1                      1.000000                  0.692383
# 2                      1.000000                  0.692383
# 3                      0.469727                  0.692383
# 4                      1.000000                       NaN
# 5                      0.991211                  0.938477
# 6                      0.991211                  0.938477
# 7                      1.000000                  0.938477
# 8                      0.413818                  0.938477
# 9                      0.414062                  0.938477
#
#   molecule_atom_1_dist_std_diff  num_atoms  flatness  bond_angle_plane  \
# 0                     -1.569336          4  0.000000          0.000000
# 1                     -0.369873          4  0.000000          0.000000
# 2                     -0.369873          4  0.000000          0.000000
# 3                     -1.569336          4  0.000000          0.000000
# 4                           NaN          4  0.000000          0.000000
# 5                     -0.163818          9  0.396373         53.959417
# 6                     -0.163818          9  0.396373         53.984077
# 7                     -0.154419          9  0.396373          0.005501
# 8                     -1.702148          9  0.396373         19.746777
# 9                     -1.701172          9  0.396373         19.722896
#
#    bond_angle_axis
# 0        90.000000
# 1        90.000000
# 2        90.000000
# 3        90.000000
# 4        90.000000
# 5         3.242966
# 6         3.218983
# 7        51.261380
# 8        65.364682
# 9        65.361512
#
# [10 rows x 85 columns]

# %%
train.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant', 'fc', 'sd', 'pso', 'dso', 'atom_index_x',
#        'atom_0', 'x_0', 'y_0', 'z_0', 'e_neg_x', 'rad_x', 'n_bonds_x',
#        'bond_lengths_mean_x', 'atom_index_y', 'atom_1', 'x_1', 'y_1', 'z_1',
#        'e_neg_y', 'rad_y', 'n_bonds_y', 'bond_lengths_mean_y',
#        'mulliken_charge_0', 'mulliken_charge_1', 'dist', 'j_bond', 'j_type',
#        'mu_0', 'mu_1', 'atom_0_en', 'atomic_mass_0', 'valence_electrons_0',
#        'atom_1_en', 'atomic_mass_1', 'valence_electrons_1', 'delta_en',
#        'molecule_couples', 'molecule_dist_mean', 'molecule_dist_min',
#        'molecule_dist_max', 'atom_0_couples_count', 'atom_1_couples_count',
#        'molecule_atom_index_0_x_1_std', 'molecule_atom_index_0_y_1_mean',
#        'molecule_atom_index_0_y_1_mean_diff',
#        'molecule_atom_index_0_y_1_mean_div', 'molecule_atom_index_0_y_1_max',
#        'molecule_atom_index_0_y_1_max_diff', 'molecule_atom_index_0_y_1_std',
#        'molecule_atom_index_0_z_1_std', 'molecule_atom_index_0_dist_mean',
#        'molecule_atom_index_0_dist_mean_diff',
#        'molecule_atom_index_0_dist_mean_div', 'molecule_atom_index_0_dist_max',
#        'molecule_atom_index_0_dist_max_diff',
#        'molecule_atom_index_0_dist_max_div', 'molecule_atom_index_0_dist_min',
#        'molecule_atom_index_0_dist_min_diff',
#        'molecule_atom_index_0_dist_min_div', 'molecule_atom_index_0_dist_std',
#        'molecule_atom_index_0_dist_std_diff',
#        'molecule_atom_index_0_dist_std_div', 'molecule_atom_index_1_dist_mean',
#        'molecule_atom_index_1_dist_mean_diff',
#        'molecule_atom_index_1_dist_mean_div', 'molecule_atom_index_1_dist_max',
#        'molecule_atom_index_1_dist_max_diff',
#        'molecule_atom_index_1_dist_max_div', 'molecule_atom_index_1_dist_min',
#        'molecule_atom_index_1_dist_min_diff',
#        'molecule_atom_index_1_dist_min_div', 'molecule_atom_index_1_dist_std',
#        'molecule_atom_index_1_dist_std_diff',
#        'molecule_atom_index_1_dist_std_div', 'molecule_atom_1_dist_mean',
#        'molecule_atom_1_dist_min', 'molecule_atom_1_dist_min_diff',
#        'molecule_atom_1_dist_min_div', 'molecule_atom_1_dist_std',
#        'molecule_atom_1_dist_std_diff', 'num_atoms', 'flatness',
#        'bond_angle_plane', 'bond_angle_axis'],
#       dtype='object')

# %%
j_types = train['type'].unique()

# %%
def select_features_pearson(j_type):
    df = train[train['type'] == j_type]

    non_feature_columns = ['scalar_coupling_constant', 'fc', 'type', 'id', 'molecule_name']
    atom_index_columns = ['atom_index_0', 'atom_index_1', 'atom_index_x', 'atom_index_y']

    X = df.select_dtypes(include=[np.number]).drop(non_feature_columns + atom_index_columns, axis=1, errors='ignore')
    y = df['scalar_coupling_constant']

    imputer = SimpleImputer(strategy='median')
    X_imputed = imputer.fit_transform(X)
    X = pd.DataFrame(X_imputed, columns=X.columns)

    X['target'] = y
    correlation_matrix = X.corr(method='pearson')
    target_correlation = correlation_matrix['target'].drop('target').sort_values(ascending=False)

    X.drop(columns='target', inplace=True)

    features = [(feature, corr) for feature, corr in target_correlation.items()]

    return features

# %%
selected_features = {}
for j_type in tqdm(j_types):
  selected_features[j_type] = select_features_pearson(j_type)

selected_features
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# {'1JHC': [('molecule_atom_1_dist_std_diff', 0.035653514386119474),
#   ('molecule_atom_1_dist_std', 0.03242600041970101),
#   ('molecule_atom_index_0_y_1_max', 0.027359339307941703),
#   ('y_0', 0.024714616598493937),
#   ('molecule_atom_index_0_y_1_mean', 0.022921478717468878),
#   ('y_1', 0.02162033769084715),
#   ('molecule_atom_index_0_y_1_std', 0.018998752049341257),
#   ('z_0', 0.016626233545529952),
#   ('sd', 0.015971271982688107),
#   ('z_1', 0.014393984480519581),
#   ('bond_lengths_mean_y', 0.014106651864461405),
#   ('mulliken_charge_1', 0.013115222628711246),
#   ('mu_0', 0.011996392655290294),
#   ('molecule_atom_index_0_dist_max_div', 0.011565815632044852),
#   ('molecule_atom_index_0_dist_max_diff', 0.010240029453531444),
#   ('bond_angle_axis', 0.00997315064575951),
#   ('molecule_atom_index_0_dist_max', 0.009496989301081714),
#   ('molecule_atom_index_0_dist_mean_div', 0.008327222204831381),
#   ('mu_1', 0.00809173482518032),
#   ('molecule_atom_index_0_dist_mean_diff', 0.006866255208771129),
#   ('atom_0_couples_count', 0.0063828098653660615),
#   ('molecule_atom_index_0_dist_mean', 0.005583790403185782),
#   ('molecule_dist_mean', 0.00355604318351128),
#   ('n_bonds_y', 0.00280577818694253),
#   ('molecule_atom_index_0_y_1_max_diff', 0.000329739230965241),
#   ('molecule_atom_index_0_dist_std_diff', 0.0003004045816844706),
#   ('molecule_atom_index_0_dist_std_div', -0.00015140879733276986),
#   ('dso', -0.00045123684915936266),
#   ('mulliken_charge_0', -0.0007496151215414845),
#   ('molecule_atom_index_0_dist_std', -0.0012398979538612248),
#   ('pso', -0.0020828220438896847),
#   ('molecule_atom_index_1_dist_std_diff', -0.0037713989362817574),
#   ('molecule_atom_index_1_dist_min_diff', -0.003788680995658598),
#   ('molecule_atom_index_1_dist_min_div', -0.0038385325439533463),
#   ('molecule_atom_index_1_dist_std_div', -0.003909575534343406),
#   ('molecule_atom_index_1_dist_std', -0.004734952384432188),
#   ('molecule_atom_1_dist_min_diff', -0.0086800266624601),
#   ('molecule_atom_1_dist_min_div', -0.008768255483664632),
#   ('x_0', -0.008971219041037442),
#   ('molecule_atom_index_0_y_1_mean_diff', -0.00915029247618409),
#   ('molecule_atom_1_dist_mean', -0.009361536498551032),
#   ('x_1', -0.010168896477423753),
#   ('molecule_atom_index_0_y_1_mean_div', -0.010371468468406787),
#   ('molecule_atom_index_1_dist_max_div', -0.010377365875287635),
#   ('molecule_atom_index_1_dist_max_diff', -0.011137163660739559),
#   ('molecule_atom_index_1_dist_max', -0.011490851836630914),
#   ('molecule_atom_index_1_dist_mean_div', -0.013311942896864146),
#   ('molecule_atom_index_1_dist_mean_diff', -0.0140147382172979),
#   ('molecule_atom_index_1_dist_mean', -0.014564160748662621),
#   ('molecule_atom_index_0_x_1_std', -0.019274711150739043),
#   ('molecule_atom_index_0_z_1_std', -0.021505456972892887),
#   ('molecule_dist_max', -0.025490506206804167),
#   ('molecule_atom_index_0_dist_min', -0.031596948559598395),
#   ('dist', -0.031596948559598395),
#   ('bond_lengths_mean_x', -0.03160231723746372),
#   ('molecule_dist_min', -0.03235983014002102),
#   ('molecule_atom_1_dist_min', -0.03280869658074557),
#   ('molecule_atom_index_1_dist_min', -0.03503211863121841),
#   ('atom_1_couples_count', -0.0367523226574012),
#   ('bond_angle_plane', -0.03765472277799555),
#   ('molecule_couples', -0.04830393139997768),
#   ('num_atoms', -0.0579787311654649),
#   ('flatness', -0.06975029512715518),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan),
#   ('molecule_atom_index_0_dist_min_diff', nan),
#   ('molecule_atom_index_0_dist_min_div', nan)],
#  '2JHH': [('z_0', 0.034186214332206644),
#   ('molecule_atom_index_1_dist_min_div', 0.023802589902255252),
#   ('molecule_atom_index_1_dist_min_diff', 0.023260588290603353),
#   ('num_atoms', 0.0202791339611699),
#   ('molecule_couples', 0.018993130567710986),
#   ('molecule_atom_index_0_z_1_std', 0.018603120947808433),
#   ('z_1', 0.016372759541650496),
#   ('pso', 0.01579945412972297),
#   ('molecule_atom_index_0_y_1_mean', 0.01164912524443372),
#   ('molecule_atom_index_1_dist_min', 0.010954537637594594),
#   ('x_0', 0.010691376402641494),
#   ('mu_0', 0.009850328845166236),
#   ('molecule_dist_mean', 0.00945555707432733),
#   ('y_0', 0.00895431069620409),
#   ('molecule_atom_index_0_y_1_max', 0.00863273071304329),
#   ('mu_1', 0.00831060855382214),
#   ('dist', 0.007702298203219684),
#   ('molecule_atom_index_0_y_1_mean_diff', 0.007384242641785858),
#   ('molecule_atom_index_0_dist_std', 0.004864441358537005),
#   ('bond_angle_axis', 0.004432078012448288),
#   ('molecule_atom_index_0_dist_std_div', 0.004297908159609205),
#   ('y_1', 0.004055734213505552),
#   ('molecule_atom_index_0_y_1_std', 0.003306264851376138),
#   ('molecule_atom_index_0_y_1_max_diff', 0.003107197475240331),
#   ('molecule_atom_index_0_dist_std_diff', 0.00300354440216316),
#   ('atom_0_couples_count', 0.0011545283035535327),
#   ('molecule_atom_index_0_dist_max', 0.0010603433765678),
#   ('molecule_dist_min', 0.0008349164343643686),
#   ('molecule_atom_index_0_dist_max_diff', 0.0003760828710263685),
#   ('mulliken_charge_1', 0.0003246882416001395),
#   ('molecule_atom_index_0_dist_max_div', -4.873096191121515e-05),
#   ('mulliken_charge_0', -0.0036030256672688584),
#   ('sd', -0.006436290095314733),
#   ('x_1', -0.007901869347438995),
#   ('flatness', -0.011112038445681913),
#   ('bond_lengths_mean_x', -0.011392817991693522),
#   ('molecule_atom_index_0_dist_min', -0.011697770212956003),
#   ('molecule_atom_index_0_dist_mean', -0.01190755206159354),
#   ('molecule_atom_index_0_dist_mean_diff', -0.013191301368373352),
#   ('molecule_atom_index_0_dist_mean_div', -0.013263575228660136),
#   ('bond_lengths_mean_y', -0.013501376827786446),
#   ('molecule_atom_index_0_dist_min_diff', -0.014935893117585981),
#   ('bond_angle_plane', -0.015722048035417116),
#   ('molecule_atom_index_0_dist_min_div', -0.01607885611109745),
#   ('molecule_atom_index_1_dist_std', -0.016880916107336334),
#   ('molecule_atom_index_1_dist_std_div', -0.017583920117777506),
#   ('molecule_atom_index_0_x_1_std', -0.01761254478190603),
#   ('molecule_atom_index_1_dist_std_diff', -0.01838163573657168),
#   ('dso', -0.018704732075681116),
#   ('molecule_atom_1_dist_min', -0.019439376156010692),
#   ('molecule_atom_index_1_dist_mean', -0.02079601626388295),
#   ('molecule_atom_index_1_dist_mean_diff', -0.021640410198280627),
#   ('molecule_atom_index_1_dist_mean_div', -0.0222488322751902),
#   ('molecule_dist_max', -0.022394784326383164),
#   ('molecule_atom_index_1_dist_max', -0.02325566325651157),
#   ('molecule_atom_index_1_dist_max_diff', -0.023674000833968194),
#   ('molecule_atom_index_1_dist_max_div', -0.0243216899487062),
#   ('molecule_atom_index_0_y_1_mean_div', -0.02781977076462896),
#   ('molecule_atom_1_dist_min_div', -0.028101580584260172),
#   ('molecule_atom_1_dist_min_diff', -0.028275167812502798),
#   ('atom_1_couples_count', -0.030622979874747523),
#   ('molecule_atom_1_dist_std', -0.03881420788732045),
#   ('molecule_atom_1_dist_std_diff', -0.040483614416130735),
#   ('molecule_atom_1_dist_mean', -0.0553389130119862),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('n_bonds_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)],
#  '1JHN': [('flatness', 0.39265637754773564),
#   ('molecule_atom_index_1_dist_min', 0.358929435062121),
#   ('num_atoms', 0.34852122093954224),
#   ('molecule_couples', 0.34273568399985466),
#   ('molecule_atom_1_dist_min', 0.34218035311591966),
#   ('molecule_dist_min', 0.34218035311591966),
#   ('bond_lengths_mean_x', 0.3081557199461068),
#   ('molecule_atom_index_0_dist_min', 0.3081557199461068),
#   ('dist', 0.3081557199461068),
#   ('molecule_dist_mean', 0.23772130558599913),
#   ('molecule_atom_index_1_dist_mean', 0.21330021793279588),
#   ('molecule_atom_index_1_dist_mean_diff', 0.20977139470370126),
#   ('molecule_dist_max', 0.20826684155763034),
#   ('molecule_atom_index_1_dist_mean_div', 0.20675654252593886),
#   ('molecule_atom_index_1_dist_min_diff', 0.1987206377574867),
#   ('molecule_atom_index_1_dist_min_div', 0.19759044172075815),
#   ('molecule_atom_index_1_dist_std', 0.19376991164504442),
#   ('molecule_atom_index_1_dist_std_div', 0.1914347889625366),
#   ('molecule_atom_index_1_dist_std_diff', 0.19059629416706106),
#   ('molecule_atom_index_0_dist_max', 0.18158753779428435),
#   ('molecule_atom_index_0_dist_max_diff', 0.17732772801313787),
#   ('molecule_atom_index_0_dist_max_div', 0.16862354803749727),
#   ('molecule_atom_index_1_dist_max', 0.156810472129997),
#   ('molecule_atom_index_1_dist_max_diff', 0.15481957071391553),
#   ('molecule_atom_index_1_dist_max_div', 0.15194414197678793),
#   ('molecule_atom_index_0_x_1_std', 0.1421769347783167),
#   ('atom_1_couples_count', 0.13921731086563272),
#   ('molecule_atom_index_0_dist_std', 0.13854592146280284),
#   ('molecule_atom_index_0_dist_mean', 0.13029150128557856),
#   ('molecule_atom_index_0_dist_std_div', 0.13014408283717202),
#   ('molecule_atom_index_0_dist_std_diff', 0.12855093998412973),
#   ('molecule_atom_1_dist_mean', 0.12697001532109536),
#   ('molecule_atom_index_0_dist_mean_diff', 0.12239047888565437),
#   ('bond_lengths_mean_y', 0.11507283303064476),
#   ('molecule_atom_index_0_z_1_std', 0.11490727811544842),
#   ('molecule_atom_index_0_dist_mean_div', 0.11353321274814356),
#   ('atom_0_couples_count', 0.0940729316158582),
#   ('bond_angle_axis', 0.08085874441583414),
#   ('molecule_atom_1_dist_min_div', 0.06035563255048376),
#   ('molecule_atom_1_dist_min_diff', 0.060137362599871645),
#   ('y_0', 0.05448908202254698),
#   ('bond_angle_plane', 0.048085286686139865),
#   ('y_1', 0.039539205330661985),
#   ('x_0', 0.02308774901515797),
#   ('molecule_atom_1_dist_std', -0.003173081468523029),
#   ('mulliken_charge_1', -0.0032499065104955767),
#   ('x_1', -0.0071712021885674306),
#   ('molecule_atom_index_0_y_1_mean_div', -0.008714273230240498),
#   ('molecule_atom_index_0_y_1_std', -0.009485354267105662),
#   ('molecule_atom_1_dist_std_diff', -0.01161654592381801),
#   ('molecule_atom_index_0_y_1_max', -0.01642107721217522),
#   ('molecule_atom_index_0_y_1_mean', -0.016929823403670375),
#   ('mu_0', -0.01945695459920231),
#   ('z_1', -0.027438563073124866),
#   ('mu_1', -0.036772452414237315),
#   ('dso', -0.03741871478613133),
#   ('z_0', -0.055416054215983876),
#   ('pso', -0.08979867014390434),
#   ('molecule_atom_index_0_y_1_max_diff', -0.11350008384853869),
#   ('molecule_atom_index_0_y_1_mean_diff', -0.11983853559526719),
#   ('sd', -0.2179377162901398),
#   ('n_bonds_y', -0.22052000289454193),
#   ('mulliken_charge_0', -0.39995919031187444),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan),
#   ('molecule_atom_index_0_dist_min_diff', nan),
#   ('molecule_atom_index_0_dist_min_div', nan)],
#  '2JHN': [('molecule_atom_index_0_dist_std', 0.2676564271385985),
#   ('molecule_atom_index_0_dist_std_div', 0.26379102980404256),
#   ('molecule_atom_index_0_dist_std_diff', 0.24145016195018976),
#   ('molecule_atom_index_0_dist_max_div', 0.1289423885797231),
#   ('molecule_atom_index_0_dist_max_diff', 0.12003321095911),
#   ('sd', 0.11797742442358777),
#   ('molecule_atom_1_dist_std_diff', 0.11739724010730931),
#   ('bond_angle_axis', 0.10442831472120177),
#   ('molecule_atom_1_dist_std', 0.09549409013986396),
#   ('molecule_atom_index_0_dist_max', 0.09450901152453556),
#   ('molecule_atom_index_0_dist_mean_diff', 0.0868305223257665),
#   ('molecule_atom_index_0_dist_mean_div', 0.08487113503411355),
#   ('molecule_atom_index_0_y_1_std', 0.08282843704767112),
#   ('molecule_atom_index_0_y_1_mean_diff', 0.07554068234895782),
#   ('molecule_atom_index_0_y_1_max_diff', 0.060731542771936396),
#   ('molecule_atom_1_dist_mean', 0.05443188887342686),
#   ('mu_0', 0.049825639724550806),
#   ('mulliken_charge_1', 0.0483270494369949),
#   ('molecule_atom_index_1_dist_mean_div', 0.0440511423177505),
#   ('molecule_atom_index_1_dist_mean_diff', 0.04068268867551596),
#   ('molecule_atom_index_0_dist_mean', 0.039610870046711724),
#   ('molecule_atom_index_1_dist_min_diff', 0.035611057738743845),
#   ('molecule_atom_index_1_dist_min_div', 0.03511935201672732),
#   ('molecule_atom_index_1_dist_min', 0.021449963628323215),
#   ('molecule_atom_index_1_dist_mean', 0.017946994698591814),
#   ('molecule_atom_index_1_dist_std_diff', 0.014041058309699426),
#   ('mulliken_charge_0', 0.010367600466287593),
#   ('molecule_atom_index_0_dist_min_diff', 0.010120728810014286),
#   ('n_bonds_y', 0.00885847096565599),
#   ('molecule_dist_mean', 0.0061114965418352886),
#   ('bond_lengths_mean_x', 0.0010708997146416626),
#   ('molecule_atom_index_1_dist_std_div', -0.008914610063292958),
#   ('molecule_atom_index_1_dist_std', -0.01332717901619503),
#   ('molecule_atom_index_0_dist_min_div', -0.020183989355989435),
#   ('y_0', -0.023500215607688158),
#   ('mu_1', -0.025491460279086976),
#   ('molecule_atom_index_1_dist_max_div', -0.028525635085660635),
#   ('molecule_atom_index_1_dist_max_diff', -0.03449783055051051),
#   ('molecule_atom_index_0_y_1_max', -0.03617886461485083),
#   ('molecule_atom_index_0_y_1_mean', -0.03771906658707962),
#   ('dso', -0.046536930908697996),
#   ('molecule_atom_index_1_dist_max', -0.049080693942053805),
#   ('molecule_atom_1_dist_min_diff', -0.049627764418454644),
#   ('molecule_atom_1_dist_min_div', -0.051489964774705826),
#   ('molecule_atom_index_0_dist_min', -0.05456824280807956),
#   ('x_1', -0.0596856280063832),
#   ('molecule_atom_1_dist_min', -0.06330606295933984),
#   ('molecule_dist_min', -0.06361131693290668),
#   ('y_1', -0.06804225609981422),
#   ('z_1', -0.07462673295424332),
#   ('molecule_atom_index_0_y_1_mean_div', -0.08668172200110313),
#   ('x_0', -0.09018103303537935),
#   ('z_0', -0.09136793623558549),
#   ('bond_lengths_mean_y', -0.09870080312876167),
#   ('dist', -0.1037530118537665),
#   ('molecule_dist_max', -0.14213181387607002),
#   ('molecule_atom_index_0_z_1_std', -0.14500832876537392),
#   ('num_atoms', -0.14641633101609094),
#   ('atom_0_couples_count', -0.15758287898964618),
#   ('atom_1_couples_count', -0.15837516520169437),
#   ('molecule_couples', -0.2005272690572747),
#   ('bond_angle_plane', -0.20241712701534745),
#   ('molecule_atom_index_0_x_1_std', -0.20471156750416297),
#   ('pso', -0.27131536357917796),
#   ('flatness', -0.36447184444372605),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)],
#  '2JHC': [('molecule_dist_mean', 0.0551772941982102),
#   ('molecule_atom_1_dist_mean', 0.04007666769770626),
#   ('flatness', 0.03400884769807558),
#   ('molecule_atom_index_1_dist_max', 0.03380433708982873),
#   ('dist', 0.03083486078282919),
#   ('molecule_atom_1_dist_std', 0.02957612292344148),
#   ('molecule_atom_index_1_dist_mean', 0.028964984653077255),
#   ('molecule_atom_index_1_dist_max_diff', 0.02837981172882732),
#   ('molecule_atom_index_0_dist_mean', 0.02625350149548067),
#   ('molecule_atom_index_1_dist_max_div', 0.02547105180114898),
#   ('molecule_atom_index_1_dist_std', 0.025074529698318956),
#   ('molecule_couples', 0.022422197469771567),
#   ('molecule_atom_index_1_dist_std_div', 0.02184126307797986),
#   ('atom_0_couples_count', 0.021695422482541235),
#   ('molecule_atom_index_0_dist_max', 0.020620972021871457),
#   ('molecule_atom_index_1_dist_mean_diff', 0.01981213343607825),
#   ('pso', 0.019672949017059967),
#   ('molecule_atom_index_0_z_1_std', 0.019319803512230747),
#   ('molecule_atom_index_1_dist_mean_div', 0.01872130154110554),
#   ('molecule_dist_max', 0.018417247010406982),
#   ('molecule_dist_min', 0.01834143893743492),
#   ('atom_1_couples_count', 0.017790078152237286),
#   ('n_bonds_y', 0.016297860610961157),
#   ('molecule_atom_index_0_x_1_std', 0.01566288235931883),
#   ('bond_lengths_mean_x', 0.015083033283283847),
#   ('molecule_atom_index_1_dist_std_diff', 0.013777560402373362),
#   ('bond_angle_plane', 0.011437395325033335),
#   ('molecule_atom_index_0_dist_max_diff', 0.011186151089516516),
#   ('x_1', 0.009958416929820295),
#   ('molecule_atom_index_0_dist_mean_diff', 0.009957182090991659),
#   ('z_1', 0.009210566123606496),
#   ('mu_1', 0.008989205097786775),
#   ('molecule_atom_index_0_dist_mean_div', 0.00854118597693495),
#   ('mu_0', 0.007715689552014231),
#   ('molecule_atom_index_0_y_1_mean', 0.006685757836232986),
#   ('z_0', 0.006251812859220819),
#   ('molecule_atom_index_0_dist_max_div', 0.00617050470068571),
#   ('molecule_atom_index_0_y_1_mean_diff', 0.005563084555159572),
#   ('num_atoms', 0.003986109229166814),
#   ('y_1', 0.0035558456184707978),
#   ('molecule_atom_index_0_dist_std', 0.003185950442702956),
#   ('molecule_atom_index_0_y_1_max', 0.0019338333870904522),
#   ('sd', 0.0019082755980280675),
#   ('bond_lengths_mean_y', 0.00157658776256746),
#   ('y_0', 0.0013397915447305405),
#   ('x_0', 0.0002745979909870462),
#   ('dso', 0.00019266789674646207),
#   ('molecule_atom_index_0_y_1_mean_div', -0.000719212194861866),
#   ('molecule_atom_index_0_y_1_max_diff', -0.0029532504527113933),
#   ('molecule_atom_index_0_dist_std_div', -0.003602986771488562),
#   ('molecule_atom_index_0_dist_min', -0.004626440335150884),
#   ('molecule_atom_1_dist_std_diff', -0.00851101033377309),
#   ('bond_angle_axis', -0.010520038365618092),
#   ('molecule_atom_index_0_dist_min_div', -0.010544072850901115),
#   ('mulliken_charge_1', -0.011509524727768155),
#   ('molecule_atom_index_1_dist_min', -0.01316612807926998),
#   ('molecule_atom_index_0_dist_std_diff', -0.014105223942610193),
#   ('molecule_atom_index_0_dist_min_diff', -0.015598477592023407),
#   ('molecule_atom_index_1_dist_min_div', -0.016667188777063587),
#   ('molecule_atom_index_1_dist_min_diff', -0.017782061533821267),
#   ('molecule_atom_index_0_y_1_std', -0.019854929595717264),
#   ('molecule_atom_1_dist_min', -0.024142045123362748),
#   ('mulliken_charge_0', -0.025176856161633034),
#   ('molecule_atom_1_dist_min_diff', -0.03661487928041103),
#   ('molecule_atom_1_dist_min_div', -0.03732088392726848),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)],
#  '3JHH': [('molecule_dist_max', 0.03480644613664939),
#   ('molecule_atom_1_dist_std', 0.025273211506975424),
#   ('bond_lengths_mean_y', 0.02300290927365997),
#   ('flatness', 0.01562320615872671),
#   ('molecule_atom_index_0_y_1_std', 0.015209717210782986),
#   ('molecule_atom_index_1_dist_std', 0.015109281710309383),
#   ('molecule_atom_index_0_dist_mean', 0.01476744258109351),
#   ('molecule_atom_index_1_dist_std_div', 0.014490326488753901),
#   ('molecule_dist_min', 0.013679174787129728),
#   ('bond_angle_plane', 0.011979895317053941),
#   ('atom_0_couples_count', 0.009308300992874358),
#   ('x_1', 0.008425496338943557),
#   ('y_1', 0.007776284460512454),
#   ('molecule_atom_index_0_z_1_std', 0.007285877978203279),
#   ('dist', 0.005590758879127543),
#   ('molecule_atom_index_1_dist_std_diff', 0.0055311551814103575),
#   ('dso', 0.004952152502021635),
#   ('molecule_atom_index_0_dist_max', 0.004881231955335194),
#   ('mu_1', 0.004260980094930384),
#   ('num_atoms', 0.004187582385931208),
#   ('molecule_atom_index_0_y_1_max', 0.0037948222891046202),
#   ('bond_angle_axis', 0.003571187292481509),
#   ('x_0', 0.0017446342570231594),
#   ('molecule_atom_index_0_dist_mean_div', 0.0015374801204676165),
#   ('bond_lengths_mean_x', 0.0013597848105673048),
#   ('molecule_atom_index_0_x_1_std', 0.001115430635963849),
#   ('molecule_couples', 0.0010555165173797318),
#   ('molecule_atom_index_0_dist_mean_diff', 0.0008772848755937518),
#   ('molecule_atom_1_dist_std_diff', 0.000545670286726519),
#   ('molecule_atom_index_0_y_1_mean', -0.00028332824467297666),
#   ('molecule_atom_index_0_dist_min', -0.0005540931822069142),
#   ('molecule_atom_index_0_dist_max_diff', -0.0011556410486619048),
#   ('molecule_atom_index_0_dist_max_div', -0.002322386359468846),
#   ('sd', -0.002593090728021213),
#   ('molecule_dist_mean', -0.002675903860128031),
#   ('z_0', -0.0027155660962126177),
#   ('molecule_atom_index_0_dist_min_div', -0.00315041162105323),
#   ('z_1', -0.0038435879168560957),
#   ('molecule_atom_index_0_y_1_mean_div', -0.005035669014545061),
#   ('molecule_atom_index_0_dist_min_diff', -0.00505472615324804),
#   ('pso', -0.005823773192631209),
#   ('mulliken_charge_0', -0.006875661549888356),
#   ('molecule_atom_1_dist_min', -0.006948377876450103),
#   ('molecule_atom_index_1_dist_min', -0.006978859197012663),
#   ('molecule_atom_index_1_dist_mean', -0.007462323133812967),
#   ('molecule_atom_1_dist_min_diff', -0.007702858519535544),
#   ('mu_0', -0.007993537085240332),
#   ('molecule_atom_1_dist_min_div', -0.008162574994167006),
#   ('molecule_atom_index_0_dist_std_diff', -0.0083865750738348),
#   ('molecule_atom_index_0_y_1_max_diff', -0.0088098218757136),
#   ('molecule_atom_index_1_dist_max', -0.008979681152143714),
#   ('molecule_atom_index_1_dist_min_diff', -0.009313093091949316),
#   ('molecule_atom_index_1_dist_min_div', -0.010121660250874421),
#   ('molecule_atom_index_0_dist_std', -0.010387826266087622),
#   ('molecule_atom_index_1_dist_mean_diff', -0.011268874787999584),
#   ('molecule_atom_index_0_dist_std_div', -0.011844874192951046),
#   ('molecule_atom_index_1_dist_mean_div', -0.01237388628983635),
#   ('y_0', -0.01405281671754159),
#   ('molecule_atom_index_1_dist_max_div', -0.014412690429751405),
#   ('molecule_atom_index_1_dist_max_diff', -0.014414814455790282),
#   ('atom_1_couples_count', -0.016585758957356027),
#   ('molecule_atom_1_dist_mean', -0.017118970458768132),
#   ('molecule_atom_index_0_y_1_mean_diff', -0.018014440616295355),
#   ('mulliken_charge_1', -0.019809509330362473),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('n_bonds_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)],
#  '3JHC': [('molecule_atom_index_0_z_1_std', 0.02517274699169173),
#   ('molecule_couples', 0.022473854970378595),
#   ('flatness', 0.022090519944689593),
#   ('atom_0_couples_count', 0.01837671196295134),
#   ('bond_lengths_mean_x', 0.01785313937175482),
#   ('molecule_dist_min', 0.012863707937258037),
#   ('num_atoms', 0.011943148586809725),
#   ('n_bonds_y', 0.009934071882767093),
#   ('molecule_atom_index_1_dist_std', 0.0098375422106729),
#   ('molecule_atom_index_1_dist_std_div', 0.008545678055387253),
#   ('molecule_dist_mean', 0.008130780263759838),
#   ('molecule_atom_index_0_x_1_std', 0.0063372960528133805),
#   ('mu_1', 0.005812771371190708),
#   ('atom_1_couples_count', 0.004849718078096539),
#   ('bond_angle_axis', 0.0047047663943114715),
#   ('x_1', 0.004390509397197939),
#   ('z_0', 0.004268554053831265),
#   ('molecule_atom_index_0_y_1_max', 0.0042091175329549875),
#   ('molecule_atom_1_dist_min', 0.003960151396102353),
#   ('y_1', 0.00359131366632023),
#   ('pso', 0.0034409885709325095),
#   ('molecule_atom_index_0_dist_mean', 0.003389767330795391),
#   ('dist', 0.00334957704903194),
#   ('molecule_atom_index_0_dist_max', 0.0032091193743012327),
#   ('molecule_atom_index_1_dist_std_diff', 0.00303075857788681),
#   ('molecule_dist_max', 0.0022769684438740047),
#   ('bond_angle_plane', 0.00180151192453352),
#   ('molecule_atom_index_0_y_1_std', 0.001487633904162123),
#   ('molecule_atom_index_0_y_1_max_diff', 0.0004839384657422134),
#   ('y_0', 0.0002810016288223797),
#   ('molecule_atom_index_0_y_1_mean', -0.0002835086633010506),
#   ('molecule_atom_index_0_dist_max_diff', -0.0009540479071854228),
#   ('molecule_atom_index_0_dist_mean_div', -0.0009854090310349813),
#   ('molecule_atom_index_0_dist_max_div', -0.0012042147302111636),
#   ('x_0', -0.0012976348338129915),
#   ('molecule_atom_index_0_y_1_mean_div', -0.0013438026651328015),
#   ('molecule_atom_index_0_dist_mean_diff', -0.0017163244969506818),
#   ('z_1', -0.0018845737400734481),
#   ('molecule_atom_1_dist_min_div', -0.0019563122803342957),
#   ('mu_0', -0.00196038408375034),
#   ('dso', -0.0021229846769105875),
#   ('sd', -0.002553475649973189),
#   ('molecule_atom_1_dist_std', -0.0027532738016736325),
#   ('molecule_atom_1_dist_min_diff', -0.0029966239540467413),
#   ('molecule_atom_index_0_dist_std', -0.003441233888141682),
#   ('molecule_atom_index_1_dist_max', -0.0036878700229370964),
#   ('molecule_atom_1_dist_std_diff', -0.0038689394233881774),
#   ('bond_lengths_mean_y', -0.0042858474652457314),
#   ('molecule_atom_1_dist_mean', -0.004369335322648252),
#   ('molecule_atom_index_0_y_1_mean_diff', -0.004734510390792402),
#   ('molecule_atom_index_0_dist_std_diff', -0.005432936442092605),
#   ('molecule_atom_index_1_dist_max_diff', -0.0059057675920022555),
#   ('molecule_atom_index_1_dist_max_div', -0.0061271816846872355),
#   ('molecule_atom_index_0_dist_std_div', -0.006190952192927847),
#   ('molecule_atom_index_0_dist_min_diff', -0.008877283037781555),
#   ('mulliken_charge_1', -0.010332998395363183),
#   ('molecule_atom_index_0_dist_min_div', -0.011355240605783938),
#   ('molecule_atom_index_0_dist_min', -0.01326731283530491),
#   ('molecule_atom_index_1_dist_mean_diff', -0.01736020895283215),
#   ('molecule_atom_index_1_dist_mean_div', -0.01839677557991691),
#   ('molecule_atom_index_1_dist_min_diff', -0.019989164697106383),
#   ('molecule_atom_index_1_dist_mean', -0.02026320992353962),
#   ('molecule_atom_index_1_dist_min_div', -0.02145229415709646),
#   ('molecule_atom_index_1_dist_min', -0.021872206351892468),
#   ('mulliken_charge_0', -0.023693272496555222),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)],
#  '3JHN': [('molecule_atom_1_dist_std', 0.0895568641470112),
#   ('pso', 0.05578844808652801),
#   ('z_1', 0.04684724966194587),
#   ('x_0', 0.043370154435666414),
#   ('molecule_atom_index_0_y_1_mean', 0.04323833791484413),
#   ('dist', 0.04032395551755244),
#   ('y_1', 0.03479961311353583),
#   ('molecule_atom_index_0_y_1_max', 0.03048208396488169),
#   ('molecule_atom_index_1_dist_mean', 0.030015534457789386),
#   ('molecule_atom_index_0_z_1_std', 0.026827754657395963),
#   ('mu_1', 0.02508597360912986),
#   ('n_bonds_y', 0.02495997226701214),
#   ('molecule_atom_1_dist_std_diff', 0.024171185763079493),
#   ('molecule_dist_mean', 0.023499210205451683),
#   ('molecule_atom_index_0_dist_std', 0.023353786126141248),
#   ('molecule_atom_index_0_dist_mean', 0.019571155664452663),
#   ('molecule_atom_index_0_dist_max', 0.019183453916183035),
#   ('y_0', 0.018093958754151568),
#   ('molecule_atom_index_1_dist_std', 0.01667023454743336),
#   ('molecule_atom_index_1_dist_min', 0.014532258874178413),
#   ('sd', 0.01164676592688878),
#   ('mu_0', 0.00981622353572858),
#   ('x_1', 0.00789760899029872),
#   ('mulliken_charge_1', 0.007603427681027082),
#   ('molecule_atom_index_1_dist_std_div', 0.005868546804083265),
#   ('z_0', 0.005606085459996125),
#   ('molecule_atom_index_1_dist_min_div', 0.0045787255459820275),
#   ('molecule_dist_max', 0.004392137154373635),
#   ('molecule_atom_index_0_y_1_mean_diff', 0.0015113541010748947),
#   ('atom_0_couples_count', 0.001489756172071674),
#   ('molecule_atom_index_1_dist_max', 0.0009922566221522988),
#   ('molecule_atom_index_1_dist_mean_div', -0.0009804066909478895),
#   ('molecule_atom_index_1_dist_min_diff', -0.001652183833290332),
#   ('mulliken_charge_0', -0.002102314160391895),
#   ('molecule_atom_index_0_y_1_std', -0.0037346757820253228),
#   ('molecule_atom_index_1_dist_mean_diff', -0.004393580625092731),
#   ('molecule_atom_index_0_dist_min', -0.004425455701960525),
#   ('molecule_atom_index_0_dist_std_div', -0.0076323466980219926),
#   ('bond_angle_plane', -0.011119884573462557),
#   ('molecule_atom_index_0_y_1_max_diff', -0.01145193283159217),
#   ('molecule_atom_index_1_dist_std_diff', -0.015024708798539904),
#   ('bond_lengths_mean_y', -0.01794217818280067),
#   ('atom_1_couples_count', -0.020998534705155406),
#   ('bond_lengths_mean_x', -0.021879619536094623),
#   ('molecule_atom_index_0_dist_max_diff', -0.028451184171036294),
#   ('molecule_atom_index_0_dist_max_div', -0.02918766212344601),
#   ('molecule_atom_index_0_dist_mean_div', -0.03037577884648804),
#   ('flatness', -0.030603479847772466),
#   ('molecule_atom_index_0_dist_mean_diff', -0.032025675936334784),
#   ('molecule_atom_index_0_dist_std_diff', -0.033984601036863245),
#   ('molecule_atom_index_1_dist_max_div', -0.03576361962131908),
#   ('molecule_atom_index_0_dist_min_div', -0.03597104243465478),
#   ('molecule_atom_index_1_dist_max_diff', -0.03779312781782884),
#   ('molecule_atom_index_0_dist_min_diff', -0.03889689506737236),
#   ('molecule_couples', -0.042848427233839616),
#   ('molecule_atom_index_0_y_1_mean_div', -0.0455078429422224),
#   ('molecule_atom_1_dist_mean', -0.048979226181775734),
#   ('num_atoms', -0.05131722533165982),
#   ('dso', -0.057251457839527724),
#   ('molecule_atom_index_0_x_1_std', -0.06187251955989012),
#   ('molecule_atom_1_dist_min', -0.0718367564327854),
#   ('molecule_atom_1_dist_min_div', -0.07880252828855865),
#   ('bond_angle_axis', -0.08497044301656544),
#   ('molecule_atom_1_dist_min_diff', -0.08558308945900871),
#   ('molecule_dist_min', -0.08799468851288594),
#   ('e_neg_x', nan),
#   ('rad_x', nan),
#   ('n_bonds_x', nan),
#   ('e_neg_y', nan),
#   ('rad_y', nan),
#   ('atom_0_en', nan),
#   ('atomic_mass_0', nan),
#   ('valence_electrons_0', nan),
#   ('atom_1_en', nan),
#   ('atomic_mass_1', nan),
#   ('valence_electrons_1', nan),
#   ('delta_en', nan)]}

# %%
threshold = 0.05
correlation_values = [abs(corr) for _, corr in selected_features['1JHC']]
median_corr = np.median(correlation_values)
std_corr = np.std(correlation_values)
if median_corr - std_corr > 0:
    threshold = median_corr - std_corr

threshold
# Out:
# 0.05

# %%
drop_features = {}

for j_type, features in selected_features.items():
  '''correlation_values = [abs(corr) for _, corr in features if not pd.isnull(corr)]
  if correlation_values:
      median_corr = np.median(correlation_values)
      std_corr = np.std(correlation_values)
      threshold = max(0.01, median_corr - (0.5 * std_corr))
  else:
      continue'''

  drop_features[j_type] = set()
  for feature, correlation in features:
    if pd.isnull(correlation):
        drop_features[j_type].add(feature)

drop_features
# Out:
# {'1JHC': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'molecule_atom_index_0_dist_min_diff',
#   'molecule_atom_index_0_dist_min_div',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '2JHH': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'n_bonds_y',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '1JHN': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'molecule_atom_index_0_dist_min_diff',
#   'molecule_atom_index_0_dist_min_div',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '2JHN': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '2JHC': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '3JHH': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'n_bonds_y',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '3JHC': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'},
#  '3JHN': {'atom_0_en',
#   'atom_1_en',
#   'atomic_mass_0',
#   'atomic_mass_1',
#   'delta_en',
#   'e_neg_x',
#   'e_neg_y',
#   'n_bonds_x',
#   'rad_x',
#   'rad_y',
#   'valence_electrons_0',
#   'valence_electrons_1'}}

# %%
for j_type in j_types:
  print(f'number of remaining features for {j_type}: {len(selected_features[j_type]) - len(drop_features[j_type])}')
# Out:
# number of remaining features for 1JHC: 63
# number of remaining features for 2JHH: 64
# number of remaining features for 1JHN: 63
# number of remaining features for 2JHN: 65
# number of remaining features for 2JHC: 65
# number of remaining features for 3JHH: 64
# number of remaining features for 3JHC: 65
# number of remaining features for 3JHN: 65

# %%
def encode(df):
  df = OrdinalEncoder.fit_transform(OrdinalEncoder(df), df)
  return df
def imp(df):
  df = SimpleImputer.fit_transform(SimpleImputer(df), df)
  return df

# %%
data_1JHC = train[train['type'] == '1JHC']
data_1JHN = train[train['type'] == '1JHN']
data_2JHH = train[train['type'] == '2JHH']
data_2JHN = train[train['type'] == '2JHN']
data_2JHC = train[train['type'] == '2JHC']
data_3JHH = train[train['type'] == '3JHH']
data_3JHN = train[train['type'] == '3JHN']
data_3JHC = train[train['type'] == '3JHC']

# %%
train_1JHC, val_1JHC = train_test_split(data_1JHC, shuffle=False, random_state=47)

train_1JHC_molecules = train_1JHC['molecule_name'].unique()
val_1JHC_molecules = np.delete(val_1JHC['molecule_name'].unique(), 0)

train_1JHC = train_1JHC[train_1JHC['molecule_name'].isin(train_1JHC_molecules)]
val_1JHC = val_1JHC[val_1JHC['molecule_name'].isin(val_1JHC_molecules)]

train_1JHN, val_1JHN = train_test_split(data_1JHN, shuffle=False, random_state=47)

train_1JHN_molecules = train_1JHN['molecule_name'].unique()
val_1JHN_molecules = np.delete(val_1JHN['molecule_name'].unique(), 0)

train_1JHN = train_1JHN[train_1JHN['molecule_name'].isin(train_1JHN_molecules)]
val_1JHN = val_1JHN[val_1JHN['molecule_name'].isin(val_1JHN_molecules)]

train_2JHH, val_2JHH = train_test_split(data_2JHH, shuffle=False, random_state=47)

train_2JHH_molecules = train_2JHH['molecule_name'].unique()
val_2JHH_molecules = np.delete(val_2JHH['molecule_name'].unique(), 0)

train_2JHH = train_2JHH[train_2JHH['molecule_name'].isin(train_2JHH_molecules)]
val_2JHH = val_2JHH[val_2JHH['molecule_name'].isin(val_2JHH_molecules)]

train_2JHN, val_2JHN = train_test_split(data_2JHN, shuffle=False, random_state=47)

train_2JHN_molecules = train_2JHN['molecule_name'].unique()
val_2JHN_molecules = np.delete(val_2JHN['molecule_name'].unique(), 0)

train_2JHN = train_2JHN[train_2JHN['molecule_name'].isin(train_2JHN_molecules)]
val_2JHN = val_2JHN[val_2JHN['molecule_name'].isin(val_2JHN_molecules)]

train_2JHC, val_2JHC = train_test_split(data_2JHC, shuffle=False, random_state=47)

train_2JHC_molecules = train_2JHC['molecule_name'].unique()
val_2JHC_molecules = np.delete(val_2JHC['molecule_name'].unique(), 0)

train_2JHC = train_2JHC[train_2JHC['molecule_name'].isin(train_2JHC_molecules)]
val_2JHC = val_2JHC[val_2JHC['molecule_name'].isin(val_2JHC_molecules)]

train_3JHH, val_3JHH = train_test_split(data_3JHH, shuffle=False, random_state=47)

train_3JHH_molecules = train_3JHH['molecule_name'].unique()
val_3JHH_molecules = np.delete(val_3JHH['molecule_name'].unique(), 0)

train_3JHH = train_3JHH[train_3JHH['molecule_name'].isin(train_3JHH_molecules)]
val_3JHH = val_3JHH[val_3JHH['molecule_name'].isin(val_3JHH_molecules)]

train_3JHC, val_3JHC = train_test_split(data_3JHC, shuffle=False, random_state=47)

train_3JHC_molecules = train_3JHC['molecule_name'].unique()
val_3JHC_molecules = np.delete(val_3JHC['molecule_name'].unique(), 0)

train_3JHC = train_3JHC[train_3JHC['molecule_name'].isin(train_3JHC_molecules)]
val_3JHC = val_3JHC[val_3JHC['molecule_name'].isin(val_3JHC_molecules)]

train_3JHN, val_3JHN = train_test_split(data_3JHN, shuffle=False, random_state=47)

train_3JHN_molecules = train_3JHN['molecule_name'].unique()
val_3JHN_molecules = np.delete(val_3JHN['molecule_name'].unique(), 0)

train_3JHN = train_3JHN[train_3JHN['molecule_name'].isin(train_3JHN_molecules)]
val_3JHN = val_3JHN[val_3JHN['molecule_name'].isin(val_3JHN_molecules)]

# %%
features_1JHC = [feature for feature,_ in selected_features['1JHC'] if feature not in drop_features['1JHC']]
features_1JHN = [feature for feature,_ in selected_features['1JHN'] if feature not in drop_features['1JHN']]
features_2JHH = [feature for feature,_ in selected_features['2JHH'] if feature not in drop_features['2JHH']]
features_2JHN = [feature for feature,_ in selected_features['2JHN'] if feature not in drop_features['2JHN']]
features_2JHC = [feature for feature,_ in selected_features['2JHC'] if feature not in drop_features['2JHC']]
features_3JHH = [feature for feature,_ in selected_features['3JHH'] if feature not in drop_features['3JHH']]
features_3JHC = [feature for feature,_ in selected_features['3JHC'] if feature not in drop_features['3JHC']]
features_3JHN = [feature for feature,_ in selected_features['3JHN'] if feature not in drop_features['3JHN']]

# %%
X_train_1JHC = train_1JHC[features_1JHC]
X_train_1JHN = train_1JHN[features_1JHN]
X_train_2JHH = train_2JHH[features_2JHH]
X_train_2JHN = train_2JHN[features_2JHN]
X_train_2JHC = train_2JHC[features_2JHC]
X_train_3JHH = train_3JHH[features_3JHH]
X_train_3JHC = train_3JHC[features_3JHC]
X_train_3JHN = train_3JHN[features_3JHN]

'''X_train_1JHC = train_1JHC
X_train_1JHN = train_1JHN
X_train_2JHH = train_2JHH
X_train_2JHN = train_2JHN
X_train_2JHC = train_2JHC
X_train_3JHH = train_3JHH
X_train_3JHC = train_3JHC
X_train_3JHN = train_3JHN'''

y_train_1JHC = train_1JHC['scalar_coupling_constant']
y_train_1JHN = train_1JHN['scalar_coupling_constant']
y_train_2JHH = train_2JHH['scalar_coupling_constant']
y_train_2JHN = train_2JHN['scalar_coupling_constant']
y_train_2JHC = train_2JHC['scalar_coupling_constant']
y_train_3JHH = train_3JHH['scalar_coupling_constant']
y_train_3JHC = train_3JHC['scalar_coupling_constant']
y_train_3JHN = train_3JHN['scalar_coupling_constant']

X_val_1JHC = val_1JHC[features_1JHC]
X_val_1JHN = val_1JHN[features_1JHN]
X_val_2JHH = val_2JHH[features_2JHH]
X_val_2JHN = val_2JHN[features_2JHN]
X_val_2JHC = val_2JHC[features_2JHC]
X_val_3JHH = val_3JHH[features_3JHH]
X_val_3JHC = val_3JHC[features_3JHC]
X_val_3JHN = val_3JHN[features_3JHN]

'''X_val_1JHC = val_1JHC
X_val_1JHN = val_1JHN
X_val_2JHH = val_2JHH
X_val_2JHN = val_2JHN
X_val_2JHC = val_2JHC
X_val_3JHH = val_3JHH
X_val_3JHC = val_3JHC
X_val_3JHN = val_3JHN'''

y_val_1JHC = val_1JHC['scalar_coupling_constant']
y_val_1JHN = val_1JHN['scalar_coupling_constant']
y_val_2JHH = val_2JHH['scalar_coupling_constant']
y_val_2JHN = val_2JHN['scalar_coupling_constant']
y_val_2JHC = val_2JHC['scalar_coupling_constant']
y_val_3JHH = val_3JHH['scalar_coupling_constant']
y_val_3JHC = val_3JHC['scalar_coupling_constant']
y_val_3JHN = val_3JHN['scalar_coupling_constant']

# %%
def eval_metric(y_true, y_pred):
  metric_value = np.sqrt(np.mean(np.square(y_true - y_pred)))
  return 'rmse', metric_value, False

def score_metric(y_true, y_pred, sample_weight):
  return np.log(np.abs(y_true - y_pred).mean())

# %%
features_1JHC
# Out:
# ['molecule_atom_1_dist_std_diff',
#  'molecule_atom_1_dist_std',
#  'molecule_atom_index_0_y_1_max',
#  'y_0',
#  'molecule_atom_index_0_y_1_mean',
#  'y_1',
#  'molecule_atom_index_0_y_1_std',
#  'z_0',
#  'sd',
#  'z_1',
#  'bond_lengths_mean_y',
#  'mulliken_charge_1',
#  'mu_0',
#  'molecule_atom_index_0_dist_max_div',
#  'molecule_atom_index_0_dist_max_diff',
#  'bond_angle_axis',
#  'molecule_atom_index_0_dist_max',
#  'molecule_atom_index_0_dist_mean_div',
#  'mu_1',
#  'molecule_atom_index_0_dist_mean_diff',
#  'atom_0_couples_count',
#  'molecule_atom_index_0_dist_mean',
#  'molecule_dist_mean',
#  'n_bonds_y',
#  'molecule_atom_index_0_y_1_max_diff',
#  'molecule_atom_index_0_dist_std_diff',
#  'molecule_atom_index_0_dist_std_div',
#  'dso',
#  'mulliken_charge_0',
#  'molecule_atom_index_0_dist_std',
#  'pso',
#  'molecule_atom_index_1_dist_std_diff',
#  'molecule_atom_index_1_dist_min_diff',
#  'molecule_atom_index_1_dist_min_div',
#  'molecule_atom_index_1_dist_std_div',
#  'molecule_atom_index_1_dist_std',
#  'molecule_atom_1_dist_min_diff',
#  'molecule_atom_1_dist_min_div',
#  'x_0',
#  'molecule_atom_index_0_y_1_mean_diff',
#  'molecule_atom_1_dist_mean',
#  'x_1',
#  'molecule_atom_index_0_y_1_mean_div',
#  'molecule_atom_index_1_dist_max_div',
#  'molecule_atom_index_1_dist_max_diff',
#  'molecule_atom_index_1_dist_max',
#  'molecule_atom_index_1_dist_mean_div',
#  'molecule_atom_index_1_dist_mean_diff',
#  'molecule_atom_index_1_dist_mean',
#  'molecule_atom_index_0_x_1_std',
#  'molecule_atom_index_0_z_1_std',
#  'molecule_dist_max',
#  'molecule_atom_index_0_dist_min',
#  'dist',
#  'bond_lengths_mean_x',
#  'molecule_dist_min',
#  'molecule_atom_1_dist_min',
#  'molecule_atom_index_1_dist_min',
#  'atom_1_couples_count',
#  'bond_angle_plane',
#  'molecule_couples',
#  'num_atoms',
#  'flatness']

# %%
X_val_1JHC.head()
# Out:
#             id     molecule_name  atom_index_0  atom_index_1  type  \
# 374780  374780  dsgdb9nsd_012706             8             0  1JHC
# 374781  374786  dsgdb9nsd_012706             9             0  1JHC
# 374782  374791  dsgdb9nsd_012706            10             0  1JHC
# 374788  374796  dsgdb9nsd_012706            11             1  1JHC
# 374802  374825  dsgdb9nsd_012706            16             6  1JHC
#
#         scalar_coupling_constant       fc        sd       pso       dso  ...  \
# 374780                   86.3750  84.6250  0.180908  0.745605  0.816895  ...
# 374781                   81.4375  79.6250  0.169434  0.872559  0.735840  ...
# 374782                   82.8750  81.1250  0.169800  0.839844  0.750000  ...
# 374788                   85.3125  84.1875  0.023697 -0.216431  1.301758  ...
# 374802                   86.3750  85.1875  0.047638 -0.163940  1.333008  ...
#
#         molecule_atom_1_dist_mean molecule_atom_1_dist_min  \
# 374780                   2.261719                 1.091797
# 374781                   2.261719                 1.091797
# 374782                   2.261719                 1.091797
# 374788                   2.261719                 1.091797
# 374802                   2.261719                 1.091797
#
#         molecule_atom_1_dist_min_diff  molecule_atom_1_dist_min_div  \
# 374780                      -0.001246                      0.999023
# 374781                      -0.001886                      0.998047
# 374782                      -0.001370                      0.998535
# 374788                      -0.010101                      0.990723
# 374802                      -0.004246                      0.996094
#
#         molecule_atom_1_dist_std  molecule_atom_1_dist_std_diff  num_atoms  \
# 374780                  0.754883                      -0.337646         18
# 374781                  0.754883                      -0.338135         18
# 374782                  0.754883                      -0.337646         18
# 374788                  0.754883                      -0.346436         18
# 374802                  0.754883                      -0.340576         18
#
#         flatness  bond_angle_plane  bond_angle_axis
# 374780  0.764094         50.739832         8.279127
# 374781  0.764094         19.023345        27.137499
# 374782  0.764094         40.665098        36.801487
# 374788  0.764094         51.203835         9.409904
# 374802  0.764094         83.006585         6.398766
#
# [5 rows x 90 columns]

# %%
y_val_1JHC
# Out:
# 374780     86.3750
# 374781     81.4375
# 374782     82.8750
# 374788     85.3125
# 374802     86.3750
#             ...
# 499964    117.5000
# 499971    107.3125
# 499972    113.3750
# 499986    101.8750
# 499990     85.1875
# Name: scalar_coupling_constant, Length: 19975, dtype: float16

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_1JHC, y_val_1JHC)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_1JHC = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_1JHC = RandomizedSearchCV(
    estimator=clf_1JHC,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_1JHC.fit(X_train_1JHC, y_train_1JHC, **fit_params)

final_params_1JHC = gs_1JHC.best_params_
final_params_1JHC.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_1JHC_final = lgb.LGBMRegressor(**final_params_1JHC)

clf_1JHC_final.fit(X_train_1JHC, y_train_1JHC)

y_pred_1JHC = clf_1JHC_final.predict(X_val_1JHC)

pred_vs_actual_1JHC = pd.DataFrame(data={
    'predictions': y_pred_1JHC,
    'actual': y_val_1JHC
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 6.53024	valid's rmse: 2.55543
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.05236	valid's rmse: 2.24774
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.22877	valid's rmse: 2.28665
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 6.04289	valid's rmse: 2.45823
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.77893	valid's rmse: 2.18608
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.97425	valid's rmse: 2.2303
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.94789	valid's rmse: 2.43883
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [995]	valid's l2: 4.79693	valid's rmse: 2.19019
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.76921	valid's rmse: 2.18385
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 6.17389	valid's rmse: 2.48473
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.06313	valid's rmse: 2.25014
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.00777	valid's rmse: 2.2378
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 6.00657	valid's rmse: 2.45083
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.83706	valid's rmse: 2.19933
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.98893	valid's rmse: 2.23359
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid's l2: 6.22878	valid's rmse: 2.49575
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 4.82557	valid's rmse: 2.19672
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 4.93595	valid's rmse: 2.2217
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 6.43811	valid's rmse: 2.53734
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.46237	valid's rmse: 2.33717
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.61148	valid's rmse: 2.36886
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.98988	valid's rmse: 2.44742
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.94569	valid's rmse: 2.22389
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.9541	valid's rmse: 2.22578
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 6.18233	valid's rmse: 2.48643
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.07188	valid's rmse: 2.25208
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 5.17071	valid's rmse: 2.27392
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 5.73536	valid's rmse: 2.39486
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 4.43272	valid's rmse: 2.1054
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 4.61934	valid's rmse: 2.14926
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 4.50597	valid's rmse: 2.12273

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_1JHN, y_val_1JHN)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_1JHN = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_1JHN = RandomizedSearchCV(
    estimator=clf_1JHN,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_1JHN.fit(X_train_1JHN, y_train_1JHN, **fit_params)

final_params_1JHN = gs_1JHN.best_params_
final_params_1JHN.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_1JHN_final = lgb.LGBMRegressor(**final_params_1JHN)

clf_1JHN_final.fit(X_train_1JHN, y_train_1JHN)

y_pred_1JHN = clf_1JHN_final.predict(X_val_1JHN)

pred_vs_actual_1JHN = pd.DataFrame(data={
    'predictions': y_pred_1JHN,
    'actual': y_val_1JHN
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [702]	valid's l2: 2.27396	valid's rmse: 1.50796
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.25596	valid's rmse: 1.1207
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [590]	valid's l2: 1.93712	valid's rmse: 1.3918
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.85282	valid's rmse: 1.36118
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.18849	valid's rmse: 1.09018
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [992]	valid's l2: 1.71856	valid's rmse: 1.31094
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [716]	valid's l2: 1.76995	valid's rmse: 1.3304
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid's l2: 1.05955	valid's rmse: 1.02934
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [836]	valid's l2: 1.51013	valid's rmse: 1.22887
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [990]	valid's l2: 2.02725	valid's rmse: 1.42382
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.28909	valid's rmse: 1.13538
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 1.75158	valid's rmse: 1.32347
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 2.28167	valid's rmse: 1.51052
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.38068	valid's rmse: 1.17502
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [962]	valid's l2: 1.98414	valid's rmse: 1.40859
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [661]	valid's l2: 1.98054	valid's rmse: 1.40732
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [760]	valid's l2: 1.2745	valid's rmse: 1.12894
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [579]	valid's l2: 1.9025	valid's rmse: 1.37931
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 2.20525	valid's rmse: 1.48501
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 1.45612	valid's rmse: 1.2067
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 2.00452	valid's rmse: 1.41581
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [993]	valid's l2: 2.10014	valid's rmse: 1.44919
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.27526	valid's rmse: 1.12927
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.86173	valid's rmse: 1.36445
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [676]	valid's l2: 2.15461	valid's rmse: 1.46786
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 1.27928	valid's rmse: 1.13105
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [876]	valid's l2: 1.99953	valid's rmse: 1.41405
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [764]	valid's l2: 1.98792	valid's rmse: 1.40994
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.139	valid's rmse: 1.06724
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [679]	valid's l2: 1.75165	valid's rmse: 1.3235
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [817]	valid's l2: 1.01453	valid's rmse: 1.00724

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_2JHH, y_val_2JHH)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_2JHH = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_2JHH = RandomizedSearchCV(
    estimator=clf_2JHH,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_2JHH.fit(X_train_2JHH, y_train_2JHH, **fit_params)

final_params_2JHH = gs_2JHH.best_params_
final_params_2JHH.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_2JHH_final = lgb.LGBMRegressor(**final_params_2JHH)

clf_2JHH_final.fit(X_train_2JHH, y_train_2JHH)

y_pred_2JHH = clf_2JHH_final.predict(X_val_2JHH)

pred_vs_actual_2JHH = pd.DataFrame(data={
    'predictions': y_pred_2JHH,
    'actual': y_val_2JHH
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.566877	valid's rmse: 0.752913
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.436094	valid's rmse: 0.660374
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.451709	valid's rmse: 0.672093
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.530732	valid's rmse: 0.728513
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.40714	valid's rmse: 0.638076
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 0.408738	valid's rmse: 0.639326
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.511957	valid's rmse: 0.715512
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.402175	valid's rmse: 0.634173
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.405654	valid's rmse: 0.636909
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.520696	valid's rmse: 0.721593
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.413873	valid's rmse: 0.643329
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.417809	valid's rmse: 0.646382
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.543272	valid's rmse: 0.73707
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.430238	valid's rmse: 0.655925
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 0.432342	valid's rmse: 0.657527
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [677]	valid's l2: 0.55561	valid's rmse: 0.745392
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [672]	valid's l2: 0.430948	valid's rmse: 0.656466
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [694]	valid's l2: 0.448089	valid's rmse: 0.669394
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.585456	valid's rmse: 0.765151
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.457642	valid's rmse: 0.676492
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.454881	valid's rmse: 0.674449
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.530254	valid's rmse: 0.728185
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.407274	valid's rmse: 0.63818
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.412267	valid's rmse: 0.64208
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.548707	valid's rmse: 0.740747
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.434805	valid's rmse: 0.659397
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [994]	valid's l2: 0.444691	valid's rmse: 0.666852
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.517124	valid's rmse: 0.719114
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.391809	valid's rmse: 0.625946
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.389288	valid's rmse: 0.623929
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 0.361799	valid's rmse: 0.601497

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_2JHN, y_val_2JHN)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_2JHN = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_2JHN = RandomizedSearchCV(
    estimator=clf_2JHN,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_2JHN.fit(X_train_2JHN, y_train_2JHN, **fit_params)

final_params_2JHN = gs_2JHN.best_params_
final_params_2JHN.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_2JHN_final = lgb.LGBMRegressor(**final_params_2JHN)

clf_2JHN_final.fit(X_train_2JHN, y_train_2JHN)

y_pred_2JHN = clf_2JHN_final.predict(X_val_2JHN)

pred_vs_actual_2JHN = pd.DataFrame(data={
    'predictions': y_pred_2JHN,
    'actual': y_val_2JHN
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.21849	valid's rmse: 1.10385
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.949098	valid's rmse: 0.974217
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.966449	valid's rmse: 0.983081
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.11497	valid's rmse: 1.05592
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.832401	valid's rmse: 0.91236
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.860106	valid's rmse: 0.927419
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [857]	valid's l2: 1.11298	valid's rmse: 1.05498
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid's l2: 0.786585	valid's rmse: 0.886896
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.882238	valid's rmse: 0.939275
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.16481	valid's rmse: 1.07926
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.85736	valid's rmse: 0.925938
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.933327	valid's rmse: 0.966088
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [935]	valid's l2: 1.22192	valid's rmse: 1.1054
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.925759	valid's rmse: 0.962164
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.974965	valid's rmse: 0.987403
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [476]	valid's l2: 1.21761	valid's rmse: 1.10345
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [538]	valid's l2: 0.901612	valid's rmse: 0.949532
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [517]	valid's l2: 1.00377	valid's rmse: 1.00188
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.22133	valid's rmse: 1.10514
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.941977	valid's rmse: 0.970555
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.00202	valid's rmse: 1.00101
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.16753	valid's rmse: 1.08052
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.858201	valid's rmse: 0.926391
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.952599	valid's rmse: 0.976012
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [662]	valid's l2: 1.19418	valid's rmse: 1.09279
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [789]	valid's l2: 0.887303	valid's rmse: 0.941967
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [832]	valid's l2: 0.999802	valid's rmse: 0.999901
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 1.13247	valid's rmse: 1.06417
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.834615	valid's rmse: 0.913573
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.866371	valid's rmse: 0.93079
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.730283	valid's rmse: 0.854566

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_2JHC, y_val_2JHC)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_2JHC = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_2JHC = RandomizedSearchCV(
    estimator=clf_2JHC,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_2JHC.fit(X_train_2JHC, y_train_2JHC, **fit_params)

final_params_2JHC = gs_2JHC.best_params_
final_params_2JHC.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_2JHC_final = lgb.LGBMRegressor(**final_params_2JHC)

clf_2JHC_final.fit(X_train_2JHC, y_train_2JHC)

y_pred_2JHC = clf_2JHC_final.predict(X_val_2JHC)

pred_vs_actual_2JHC = pd.DataFrame(data={
    'predictions': y_pred_2JHC,
    'actual': y_val_2JHC
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.7535	valid's rmse: 1.3242
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.47581	valid's rmse: 1.21483
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.5769	valid's rmse: 1.25575
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 1.66873	valid's rmse: 1.29179
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.41613	valid's rmse: 1.19001
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.502	valid's rmse: 1.22556
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [995]	valid's l2: 1.60342	valid's rmse: 1.26626
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.28301	valid's rmse: 1.1327
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.33233	valid's rmse: 1.15427
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.70846	valid's rmse: 1.30708
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.48651	valid's rmse: 1.21922
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.63099	valid's rmse: 1.2771
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.6727	valid's rmse: 1.29333
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.42358	valid's rmse: 1.19314
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.56552	valid's rmse: 1.25121
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.67256	valid's rmse: 1.29328
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.37985	valid's rmse: 1.17467
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 1.45271	valid's rmse: 1.20528
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.8624	valid's rmse: 1.3647
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.65921	valid's rmse: 1.2881
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.80547	valid's rmse: 1.34368
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.66842	valid's rmse: 1.29167
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.44379	valid's rmse: 1.20158
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.56168	valid's rmse: 1.24967
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.70775	valid's rmse: 1.30681
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.48284	valid's rmse: 1.21772
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.60062	valid's rmse: 1.26516
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 1.56753	valid's rmse: 1.25201
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.28418	valid's rmse: 1.13321
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.38291	valid's rmse: 1.17597
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.20444	valid's rmse: 1.09747

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_3JHH, y_val_3JHH)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_3JHH = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_3JHH = RandomizedSearchCV(
    estimator=clf_3JHH,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_3JHH.fit(X_train_3JHH, y_train_3JHH, **fit_params)

final_params_3JHH = gs_3JHH.best_params_
final_params_3JHH.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_3JHH_final = lgb.LGBMRegressor(**final_params_3JHH)

clf_3JHH_final.fit(X_train_3JHH, y_train_3JHH)

y_pred_3JHH = clf_3JHH_final.predict(X_val_3JHH)

pred_vs_actual_3JHH = pd.DataFrame(data={
    'predictions': y_pred_3JHH,
    'actual': y_val_3JHH
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.626031	valid's rmse: 0.791221
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.486618	valid's rmse: 0.69758
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.502022	valid's rmse: 0.708535
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.588667	valid's rmse: 0.767246
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.461285	valid's rmse: 0.679179
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.466018	valid's rmse: 0.682655
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [894]	valid's l2: 0.565817	valid's rmse: 0.752208
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [993]	valid's l2: 0.436961	valid's rmse: 0.661031
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.451042	valid's rmse: 0.671596
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.597553	valid's rmse: 0.773016
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.477346	valid's rmse: 0.690902
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.485531	valid's rmse: 0.696801
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid's l2: 0.590864	valid's rmse: 0.768677
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.469946	valid's rmse: 0.685526
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.485106	valid's rmse: 0.696495
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [984]	valid's l2: 0.59813	valid's rmse: 0.773388
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.464902	valid's rmse: 0.681837
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.473867	valid's rmse: 0.68838
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.634626	valid's rmse: 0.796634
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.528263	valid's rmse: 0.726817
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.521221	valid's rmse: 0.721956
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.584248	valid's rmse: 0.764361
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.471488	valid's rmse: 0.68665
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.480867	valid's rmse: 0.693446
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 0.607332	valid's rmse: 0.779315
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.48454	valid's rmse: 0.696089
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.503903	valid's rmse: 0.709861
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [988]	valid's l2: 0.566177	valid's rmse: 0.752447
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.431362	valid's rmse: 0.656782
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.451317	valid's rmse: 0.671801
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [994]	valid's l2: 0.407786	valid's rmse: 0.638581

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_3JHC, y_val_3JHC)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_3JHC = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_3JHC = RandomizedSearchCV(
    estimator=clf_3JHC,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_3JHC.fit(X_train_3JHC, y_train_3JHC, **fit_params)

final_params_3JHC = gs_3JHC.best_params_
final_params_3JHC.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_3JHC_final = lgb.LGBMRegressor(**final_params_3JHC)

clf_3JHC_final.fit(X_train_3JHC, y_train_3JHC)

y_pred_3JHC = clf_3JHC_final.predict(X_val_3JHC)

pred_vs_actual_3JHC = pd.DataFrame(data={
    'predictions': y_pred_3JHC,
    'actual': y_val_3JHC
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.69435	valid's rmse: 1.30167
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 1.41022	valid's rmse: 1.18753
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 1.45088	valid's rmse: 1.20453
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.66983	valid's rmse: 1.29222
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.414	valid's rmse: 1.18912
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.42332	valid's rmse: 1.19303
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.5737	valid's rmse: 1.25447
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 1.26797	valid's rmse: 1.12604
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.28273	valid's rmse: 1.13258
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.74462	valid's rmse: 1.32084
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.49291	valid's rmse: 1.22185
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.48883	valid's rmse: 1.22018
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.64136	valid's rmse: 1.28116
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.38371	valid's rmse: 1.17631
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 1.37693	valid's rmse: 1.17343
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.61093	valid's rmse: 1.26922
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.30785	valid's rmse: 1.14361
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.31027	valid's rmse: 1.14467
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 1.85989	valid's rmse: 1.36378
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.61117	valid's rmse: 1.26932
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.63184	valid's rmse: 1.27743
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.72295	valid's rmse: 1.31261
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.43605	valid's rmse: 1.19835
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.45713	valid's rmse: 1.20712
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.69766	valid's rmse: 1.30294
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.45448	valid's rmse: 1.20602
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.46064	valid's rmse: 1.20857
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.55673	valid's rmse: 1.24769
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.24863	valid's rmse: 1.11742
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.25484	valid's rmse: 1.1202
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 1.14939	valid's rmse: 1.0721

# %%
fit_params={'eval_metric' : eval_metric,
            'eval_set' : [(X_val_3JHN, y_val_3JHN)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            'callbacks': [lgb.early_stopping(stopping_rounds=30, verbose=True)]}

param_test ={'num_leaves': [x for x in range(20, 80, 10)],
             'min_child_samples': [x for x in range(200, 400, 20)],
             'min_child_weight': [1e-3, 1e-2, 1e-1, 1, 10],
             'subsample': uniform(loc=0.6, scale=0.4),
             'colsample_bytree': uniform(loc=0.6, scale=0.4),
             'reg_alpha': [0, 1e-1, 1, 5, 10],
             'reg_lambda': [0, 1e-1, 1, 5, 10],
             'learning_rate': uniform(loc=0.01, scale=0.2)}

clf_3JHN = lgb.LGBMRegressor(max_depth=-1, random_state=47, n_jobs=-1, n_estimators=1000, verbose=-1)

gs_3JHN = RandomizedSearchCV(
    estimator=clf_3JHN,
    param_distributions=param_test,
    n_iter=10,
    cv=3,
    refit=True,
    random_state=47,
    scoring='neg_mean_squared_error')

gs_3JHN.fit(X_train_3JHN, y_train_3JHN, **fit_params)

final_params_3JHN = gs_3JHN.best_params_
final_params_3JHN.update({
    'n_estimators': 2000,
    'max_depth': -1,
    'random_state': 47,
    'n_jobs': -1,
    'verbose': -1
})

clf_3JHN_final = lgb.LGBMRegressor(**final_params_3JHN)

clf_3JHN_final.fit(X_train_3JHN, y_train_3JHN)

y_pred_3JHN = clf_3JHN_final.predict(X_val_3JHN)

pred_vs_actual_3JHN = pd.DataFrame(data={
    'predictions': y_pred_3JHN,
    'actual': y_val_3JHN
})
# Out:
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [562]	valid's l2: 0.431437	valid's rmse: 0.656839
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [842]	valid's l2: 0.348429	valid's rmse: 0.590279
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [775]	valid's l2: 0.420516	valid's rmse: 0.648472
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [994]	valid's l2: 0.399601	valid's rmse: 0.63214
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [978]	valid's l2: 0.325362	valid's rmse: 0.570405
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [970]	valid's l2: 0.388827	valid's rmse: 0.62356
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [792]	valid's l2: 0.405316	valid's rmse: 0.636644
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [923]	valid's l2: 0.304617	valid's rmse: 0.551921
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.362637	valid's rmse: 0.602193
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.408689	valid's rmse: 0.639288
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.32931	valid's rmse: 0.573855
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.398188	valid's rmse: 0.631021
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [756]	valid's l2: 0.446919	valid's rmse: 0.66852
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [741]	valid's l2: 0.363312	valid's rmse: 0.602754
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [705]	valid's l2: 0.443744	valid's rmse: 0.666141
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [350]	valid's l2: 0.443464	valid's rmse: 0.665931
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [366]	valid's l2: 0.359603	valid's rmse: 0.599669
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [354]	valid's l2: 0.445989	valid's rmse: 0.667824
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.420088	valid's rmse: 0.648142
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.338591	valid's rmse: 0.581885
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.411163	valid's rmse: 0.64122
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.419281	valid's rmse: 0.647519
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.324831	valid's rmse: 0.569939
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [997]	valid's l2: 0.399269	valid's rmse: 0.631877
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [558]	valid's l2: 0.439314	valid's rmse: 0.662807
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [518]	valid's l2: 0.357736	valid's rmse: 0.59811
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [572]	valid's l2: 0.430277	valid's rmse: 0.655955
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [786]	valid's l2: 0.407781	valid's rmse: 0.638577
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid's l2: 0.316669	valid's rmse: 0.562733
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid's l2: 0.376896	valid's rmse: 0.613919
# Training until validation scores don't improve for 30 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid's l2: 0.300948	valid's rmse: 0.548587
